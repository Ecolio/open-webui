# %%
from langchain_community.document_loaders import PyPDFLoader

# Load the PDF and extract text
loader = PyPDFLoader("/Users/lijou/Documents/Documents/Courses/Coursera/AdvancedDjango/Inro_Document.pdf")
pages = loader.load()
text = '\n'.join([page.page_content for page in pages])

# %%
import ollama


question = 'is there contradictions in the document?'

messages = [
  {
    'role': 'system',
    'content': f'Use the following document to answer the question: {text}',
  },
  {
    'role': 'user',
    'content': question,
  },
]

response = ollama.chat(model='llama3-gradient', messages=messages)
print(response['message']['content'])
# Out:
# Yes, I can see a few issues with this document. There are no specific guidelines that indicate when the document is for. The information could be applied to people of any age or experience level and it doesn't have any guidance on how long it should take to read through the entire content. There isn't even an introduction in this article. It starts off with the statement that this is a 10 minute lesson plan, which helps somewhat but I still need to know what I am supposed to be doing while I read this document. The objectives are also not clear and if there was some kind of scenario or activity at the start it would give me a better idea of how to use this as my guide. It could have been written in a more detailed and organized fashion than this. There is no clear plan for what to do while reading this document, so that makes it hard to read through without any specific ideas on where I should be in the process at each step.

# %%
import ollama

# Define the questions
questions = [
    "Are there any repeated sections or sentences in the document?",
    "Are there any contradictions or logical errors in the document?",
    "Does the narrative flow smoothly and logically throughout the document?",
    "Are there any parts of the document that are unclear or difficult to understand?"
]

# Initialize an empty list to store the answers
answers = []

# Iterate over each question
for question in questions:
    messages = [
        {
            'role': 'system',
            'content': f'Use the following document to answer the question: {text}',
        },
        {
            'role': 'user',
            'content': question,
        },
    ]
    print(messages)
    response = ollama.chat(model='llama3', messages=messages)
    # Store the answer in the answers list
    answers.append(response['message']['content'])

# Define a final question to summarize all the feedback
final_question = "Summarize the following feedback on the document: " + ", ".join(answers)

# Get the final summary from the model
messages = [
    {
        'role': 'system',
        'content': f'Use the following feedback to answer the question: {", ".join(answers)}',
    },
    {
        'role': 'user',
        'content': final_question,
    },
]
print(messages)
final_response = ollama.chat(model='llama3-gradient', messages=messages)
print(final_response['message']['content'])
# Out:
# [{'role': 'system', 'content': 'Use the following document to answer the question: Learning\tObjectives\nSetup\ta\tblog\tapplication\tin\tDjango\nConﬁgure\tthe\tdev\tserver\tto\trun\tinside\tthe\tCodio\nplatform\nRun\tdatabase\tmigrations\nCreate\tthe\t\nTag\n\t\nand\t\nPost\n\t\nmodels\nRegister\tthe\t\nTag\n\t\nand\t\nPost\n\t\nmodels\twith\tDjango\tAdmin\nCreate\ta\tpost\tthrough\tDjango\tAdmin\nConnecting\tto\tGitHub\nConnecting\tto\tGitHub\nOver\tfour\tcourses,\tyou\tare\tgoing\tto\tbuild\ta\tDjango\tapp.\tIn\torder\tto\tget\tyour\ncode\tin\tevery\tassignment,\tyou\tare\tgoing\tto\tuse\tGitHub.\tIf\tyou\tdo\tnot\tyet\nhave\tan\taccount,\tplease\t\ncreate\tone\n\t\nnow.\tWe\tare\tgoing\tto\tclone\ta\trepo\tthat\nwill\tcontain\tthe\tcode\tfor\tyour\tDjango\tapp.\nConnecting\tGitHub\tand\tCodio\nYou\tneed\tto\t\nconnect\n\t\nGitHub\tto\tyour\tCodio\taccount.\tThis\tonly\tneeds\tto\tbe\ndone\tone\ttime.\nIn\tyour\tCodio\taccount,\tclick\ton\tyour\tusername\nClick\ton\t\nApplications
# ...

# %%
import ollama

# Define the questions
questions = [
    "Are there any repeated sections or sentences in the document?",
    "Are there any contradictions or logical errors in the document?",
    "Does the narrative flow smoothly and logically throughout the document?",
    "Are there any parts of the document that are unclear or difficult to understand?"
]

# Define the language models to use
models = ['mistral', 'phi3', 'qwen2']

# Initialize an empty list to store all answers from each model for each question
all_answers = []

# Iterate over each question
for question in questions:
    print(f"Question: {question}")  # Print the original text of the question
    question_answers = []  # Reset the list of answers for this question
    # For each language model, get the answer for this question
    for model in models:
        print(f"Model: {model}")  # Print the name of the current model
        messages = [
            {
                'role': 'system',
                'content': f'Use the following document to answer the question: {text}',
            },
            {
                'role': 'user',
                'content': question,
            },
        ]
        # print(messages)
        response = ollama.chat(model=model, messages=messages)
        print(response)
        # Store the answer in the list of answers for this question
        question_answers.append(response['message']['content'])
    # Synthesize the answers from all models for this question using Llama3
    synthesis_question = "Summarize the following feedback on the document: " + ", ".join(question_answers)
    messages = [
        {
            'role': 'system',
            'content': f'Use the following feedback to answer the question: {", ".join(question_answers)}',
        },
        {
            'role': 'user',
            'content': synthesis_question,
        },
    ]
    print("Model: llama3")  # Print the name of Llama3 model for this part
    #print(messages)
    final_response = ollama.chat(model='llama3', messages=messages)
    print(final_response)
    # Store the synthesized answer in the list of all answers
    all_answers.append(final_response['message']['content'])

# Define a final question to summarize all the feedback from Llama3's synthesis
final_question = "Summarize the overall feedback on the document: " + ", ".join(all_answers)

# Get the final summary from the model Llama3-gradient
messages = [
    {
        'role': 'system',
        'content': f'Use the following feedback to answer the question: {", ".join(all_answers)}',
    },
    {
        'role': 'user',
        'content': final_question,
    },
]
print("Model: llama3-gradient")  # Print the name of Llama3-gradient model for this part
#print(messages)
final_synthesis = ollama.chat(model='llama3-gradient', messages=messages)
print(final_synthesis['message']['content'])
# Out:
# Question: Are there any repeated sections or sentences in the document?
# Model: mistral
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 35
#      24 messages = [
#      25     {
#      26         'role': 'system',
#    (...)
#      32     },
#      33 ]
#      34 # print(messages)
# ---> 35 response = ollama.chat(model=model, messages=messages)
#      36 print(response)
#      37 # Store the answer in the list of answers for this question
#
# File ~/GitHub/Ecolio/owUI/.venv/lib/python3.11/site-packages/ollama/_client.py:180, in Client.chat(self, model, messages, stream, format, options, keep_alive)
#     177   if images := message.get('images'):
#     178     message['images'] = [_encode_image(image) for image in images]
# --> 180 return self._request_stream(
#     181   'POST',
#     182   '/api/chat',
#     183   json={
#     184     'model': model,
# ...

# %%
# read in a md file in variable named text
with open('/Users/lijou/Documents/Documents/Project/Notes_Docs/PreAward/exemples/Binder1/Binder1.md', 'r') as file:
    text = file.read()

# %%
import ollama

# Define the questions
questions = [
    "Are there any repeated sections or sentences in the document?",
    "Are there any contradictions or logical errors in the document?",
    "Does the narrative flow smoothly and logically throughout the document?",
    "Are there any parts of the document that are unclear or difficult to understand?"
]

# Define the language models to use
models = ['mistral', 'phi3', 'qwen2']

# Initialize an empty list to store all answers from each model for all questions
all_answers = []

# Iterate over each model
for model in models:
    print(f"Model: {model}")  # Print the name of the current model
    model_answers = []
    # For each question, get the answer from this model
    for question in questions:
        print(f"Question: {question}")  # Print the original text of the question
        messages = [
            {
                'role': 'system',
                'content': f'Use the following document to answer the question: {text}',
            },
            {
                'role': 'user',
                'content': question,
            },
        ]
        response = ollama.chat(model=model, messages=messages)
        model_answers.append(response['message']['content'])
    # After answering all questions with this model, add these answers to the list of all answers
    all_answers.append(model_answers)

# Now that we have answered all questions with each model, synthesize the answers with Llama3
gemma2_synthesis = []
for i in range(len(questions)):  # For each question
    question_answers = [model_answers[i] for model_answers in all_answers]  # Get the answers to this question from all models
    synthesis_question = "Summarize the following feedback on the document: " + ", ".join(question_answers)
    messages = [
        {
            'role': 'system',
            'content': f'Use the following feedback to answer the question: {", ".join(question_answers)}',
        },
        {
            'role': 'user',
            'content': synthesis_question,
        },
    ]
    print("Model: gemma2")  # Print the name of Llama3 model for this part
    final_response = ollama.chat(model='gemma2', messages=messages)
    gemma2_synthesis.append(final_response['message']['content'])

# Finally, use Llama3-gradient to summarize all the feedback from Llama3's synthesis
final_question = "Summarize the overall feedback on the document: " + ", ".join(gemma2_synthesis)
messages = [
    {
        'role': 'system',
        'content': f'Use the following feedback to answer the question: {", ".join(gemma2_synthesis)}',
    },
    {
        'role': 'user',
        'content': final_question,
    },
]
print("Model: llama3-gradient")  # Print the name of Llama3-gradient model for this part
final_synthesis = ollama.chat(model='llama3-gradient', messages=messages)
print(final_synthesis['message']['content'])
# Out:
# Model: mistral
# Question: Are there any repeated sections or sentences in the document?
# Question: Are there any contradictions or logical errors in the document?
# Question: Does the narrative flow smoothly and logically throughout the document?
# Question: Are there any parts of the document that are unclear or difficult to understand?
# Model: phi3
# Question: Are there any repeated sections or sentences in the document?
# Question: Are there any contradictions or logical errors in the document?
# Question: Does the narrative flow smoothly and logically throughout the document?
# Question: Are there any parts of the document that are unclear or difficult to understand?
# Model: qwen2
# Question: Are there any repeated sections or sentences in the document?
# Question: Are there any contradictions or logical errors in the document?
# Question: Does the narrative flow smoothly and logically throughout the document?
# ...

# %%
print(text)
# Out:
# # Cohabitation And Optimal Reconciliation: Integrating Territorial Transformations And Ecological Resilience Critter
#
# [This document is tagged. Do not delete the tags; they are needed for processing.] \#@APP-FORM-HERIAIA@\#
# List of participants
#
# | PARTICIPANT NO.PARTICIPANT ORGANISATION NAME                                                                                                                                                                                                                                                                         | SHORT NAME COUNTRY                                                |         |    |
# ...

# %%
# read in a md file in variable named text
with open('/Users/lijou/Documents/Documents/Project/Notes_Docs/PreAward/exemples/Binder1/Binder1.md', 'r') as file:
    text = file.read()

# %%
import ollama
from nltk import sent_tokenize, word_tokenize
#from collections import deque

def split_document(text, max_words=4000):
    sections = text.split('2. Impact')
    print('section1 split')
    sections[1] = '2. Impact' + sections[1]  # Add the section title back to the second section
    print('section2 split')
    sections = [section.split('3. Quality And Efficiency Of The Implementation') for section in sections]
    flattened_sections = [item for sublist in sections for item in sublist]
    if len(flattened_sections) == 3:
        flattened_sections[2] = '3. Quality And Efficiency Of The Implementation' + flattened_sections[2]
        print('section3 split')

    chunks = []
    for section in flattened_sections:
        sentences = sent_tokenize(section)
        current_chunk = ''
        word_count = 0

        for sentence in sentences:
            sentence_word_count = len(word_tokenize(sentence))
            if word_count + sentence_word_count > max_words:
                chunks.append(current_chunk.strip())
                current_chunk = ''
                word_count = 0

            current_chunk += ' ' + sentence
            word_count += sentence_word_count

        if current_chunk:
            chunks.append(current_chunk.strip())

    return chunks


document_chunks = split_document(text)  # Assuming 'text' is your document
# Out:
# section1 split
# section2 split
# section3 split

# %%
# Print the list of document chunks with only the first 2 lines and the last 2 lines of each chunk
for i, chunk in enumerate(document_chunks):
    lines = chunk.split('\n')
    print(f"Chunk {i + 1}:")
    print('\n'.join(lines[:2] + lines[-2:]))
    print('---')
# Out:
# Chunk 1:
# # Cohabitation And Optimal Reconciliation: Integrating Territorial Transformations And Ecological Resilience Critter
#
#
# ...

# %%
import ollama

# Define the questions
questions = [
    "Are there any repeated sections or sentences in the document?",
    "Are there any contradictions or logical errors in the document?",
    "Does the narrative flow smoothly and logically throughout the document?",
    "Are there any parts of the document that are unclear or difficult to understand?"
]

# Define the language models to use
models = ['mistral', 'phi3', 'qwen2']

# Initialize an empty list to store all answers from each model for all questions
all_answers = []

# Iterate over each model
for chunk in document_chunks:
    for model in models:
        print(f"Model: {model}")
        model_answers = []
        for question in questions:
            print(f"Question: {question}")
            messages = [
                {
                    'role': 'system',
                    'content': f'Use the following document to answer the question: {chunk}',
                },
                {
                    'role': 'user',
                    'content': question,
                },
            ]
            response = ollama.chat(model=model, messages=messages)
            model_answers.append(response['message']['content'])
        all_answers.append(model_answers)

# Now that we have answered all questions with each model, synthesize the answers with Llama3
gemma2_synthesis = []
for i in range(len(questions)):  # For each question
    question_answers = [model_answers[i] for model_answers in all_answers]  # Get the answers to this question from all models
    synthesis_question = "Summarize the following feedback on the document: " + ", ".join(question_answers)
    messages = [
        {
            'role': 'system',
            'content': f'Use the following feedback to answer the question: {", ".join(question_answers)}',
        },
        {
            'role': 'user',
            'content': synthesis_question,
        },
    ]
    print("Model: gemma2")  # Print the name of Llama3 model for this part
    final_response = ollama.chat(model='gemma2', messages=messages)
    gemma2_synthesis.append(final_response['message']['content'])

# Finally, use Llama3-gradient to summarize all the feedback from Llama3's synthesis
final_question = "Summarize the overall feedback on the document: " + ", ".join(gemma2_synthesis)
messages = [
    {
        'role': 'system',
        'content': f'Use the following feedback to answer the question: {", ".join(gemma2_synthesis)}',
    },
    {
        'role': 'user',
        'content': final_question,
    },
]
print("Model: llama3-gradient")  # Print the name of Llama3-gradient model for this part
final_synthesis = ollama.chat(model='llama3-gradient', messages=messages)
print(final_synthesis['message']['content'])
# Out:
# Model: mistral
# Question: Are there any repeated sections or sentences in the document?
# Question: Are there any contradictions or logical errors in the document?
# Question: Does the narrative flow smoothly and logically throughout the document?
# Question: Are there any parts of the document that are unclear or difficult to understand?
# Model: phi3
# Question: Are there any repeated sections or sentences in the document?
# Question: Are there any contradictions or logical errors in the document?
# Question: Does the narrative flow smoothly and logically throughout the document?
# Question: Are there any parts of the document that are unclear or difficult to understand?
# Model: qwen2
# Question: Are there any repeated sections or sentences in the document?
# Question: Are there any contradictions or logical errors in the document?
# Question: Does the narrative flow smoothly and logically throughout the document?
# ...

# %%
print(gemma2_synthesis)
# Out:
# ['It seems you\'re analyzing a document and trying to determine if there\'s any textual repetition. You\'re doing a great job of breaking down the document\'s structure and identifying potential areas of overlap. \n\nHowever, remember that **"repetition" can be subjective**.  \n\n* **Context matters:**  Some phrases or ideas might be repeated because they are essential to understanding the project\'s overall goals and activities. For example, mentioning "landscape-level interventions" repeatedly might be necessary to emphasize the project\'s focus.\n* **Standardized language:** Project reports often use specific terminology and formatting conventions. This can create the *illusion* of repetition, but it\'s actually a way to ensure consistency and clarity.\n\n**Here\'s how to refine your analysis:**\n\n1. **Define "Repetition" Clearly:** Decide what constitutes repetition for your analysis. Is it identical phrasing, similar ideas expressed differently, or a combination of both?\n\n2. 
# ...

# %%
# for local file
from magic_doc.docconv import DocConverter, S3Config
converter = DocConverter(s3_config=None)
markdown_content, time_cost = converter.convert("/Users/lijou/Documents/Documents/Project/Notes_Docs/PreAward/exemples/Binder1.pdf", conv_timeout=300)
# Out:
# 2024-07-15 11:29:40.415 | INFO     | magic_pdf.libs.pdf_check:detect_invalid_chars:57 - cid_count: 0, text_len: 39523, cid_chars_radio: 0.0
# 2024-07-15 11:29:40.489 | INFO     | magic_doc.contrib.pdf.pdf_extractor:run:70 - stream io data is digital pdf

# %%
print(markdown_content)
# Out:
# Call: [HORIZON-CL6-2024-FARM2FORK-01-1] — [Agro-pastoral/outdoor livestock systems and wildlife management]
#
# Part B - Page 1 of 50
#
# COHABITATION AND OPTIMAL RECONCILIATION: INTEGRATING TERRITORIAL TRANSFORMATIONS AND ECOLOGICAL RESILIENCE
#
# CRITTER
#
# [This document is tagged. Do not delete the tags; they are needed for processing.] #@APP-FORM-HERIAIA@# List of participants
#
# PARTICIPANT NO. PARTICIPANT ORGANISATION NAME SHORT NAME COUNTRY
#
# 1 (Coordinator) Syddansk Universitet SDU DK
#
# 2 Lapin Yliopisto UOL FI
#
# 3 Università degli Studi di Padova UNIPD IT
#
# 4 Centro de Investigacion y Tecnologia Agroalimentaria de Aragon CITA ES
#
# 5 Association WWF Bulgaria WWF-BG BG
#
# 6 WWF Slovensko WWF-SK SK
#
# 7 Zavod za Gozdove Slovenije - Slovenia Forest Service SFS SI
#
# 8 Schola Campesina APS CAMP IT
#
# 9 De Surdurulebilir Enerji ve Insaat Sanayi Ticaret Limited Sirketi DEM TR
#
# 10 Luonnonvarakeskus - Natural Resources Institute Finland LUKE FI
#
# ...

# %%
import ollama

# Define the questions
questions = [
    "Are there any repeated sections or sentences in the document?",
    "Are there any contradictions or logical errors in the document?",
    "Does the narrative flow smoothly and logically throughout the document?",
    "Are there any parts of the document that are unclear or difficult to understand?"
]

# Define the personalities to use with InternLM2 model
personalities = [
    'Highly logical and analytical, focusing on facts and figures.',
    'Emphasizes teamwork and collaboration, looking for evidence of successful collaborations and potential for future collaborations.',
    'Forward-thinking and innovative, evaluating the grant application based on its potential to drive innovation and create new opportunities.'
]

# Initialize an empty list to store all answers from each personality for all questions
all_answers = []

document_text = markdown_content  # Assign your document content here

# Iterate over each personality
for personality in personalities:
    print(f"Personality: {personality}")
    model_answers = []
    # For each question, get the answer based on this personality
    for question in questions:
        print(f"Question: {question}")
        messages = [
            {
                'role': 'system',
                'content': f'You are {personality}. Use the following document to answer the question. Be sure to provide a summary of your findings at the end.\n\nDocument: {document_text}',
            },
            {
                'role': 'user',
                'content': question,
            },
        ]
                # Set options including the increased context window
        options = {
            "num_ctx": 40000  # Increase context window to 128k tokens
        }
        response = ollama.chat(
            model='InternLM2',
            messages=messages,
            options=options  # Pass the options dictionary
        )
        #response = ollama.chat(model='InternLM2', messages=messages)
        model_answers.append(response['message']['content'])
    # After answering all questions with this personality, add these answers to the list of all answers
    all_answers.append(model_answers)

# Now that we have answered all questions with each model, synthesize the answers with Llama3
gemma2_synthesis = []
for i in range(len(questions)):  # For each question
    question_answers = [model_answers[i] for model_answers in all_answers]  # Get the answers to this question from all models
    synthesis_question = "Summarize and consolidate the following feedback on the document: " + ", ".join(question_answers)
    messages = [
        {
            'role': 'system',
            'content': f'You are a highly skilled synthetic analyzer. Your task is to summarize, consolidate and present in a coherent manner the feedback provided by multiple models on the document: {", ".join(question_answers)}. Ensure to highlight any common insights or discrepancies from different perspectives.',
        },
        {
            'role': 'user',
            'content': synthesis_question,
        },
    ]
    final_response = ollama.chat(model='gemma2', messages=messages)
    gemma2_synthesis.append(final_response['message']['content'])

# Print the synthesized answers once
print("Model: gemma2")
for i, answer in enumerate(gemma2_synthesis):
    print(f"Question: {questions[i]}")
    print(answer)

# Assume `document_text` is the variable holding the full text of the document

# Finally, use Llama3-gradient to summarize all the feedback from Llama3's synthesis
final_question = f"Using the provided feedback and the context of the document: '{document_text}', summarize the overall feedback on the document: " + ", ".join(gemma2_synthesis)
messages = [
    {
        'role': 'system',
        'content': f'Use the following feedback to answer the question and properly reference parts of the document when necessary: {", ".join(gemma2_synthesis)}',
    },
    {
        'role': 'user',
        'content': final_question,
    },
]
print("Model: llama3-gradient")  # Print the name of Llama3-gradient model for this part
final_synthesis = ollama.chat(model='llama3-gradient', messages=messages)
print(final_synthesis['message']['content'])
# Out:
# Personality: Highly logical and analytical, focusing on facts and figures.
# Question: Are there any repeated sections or sentences in the document?
# Question: Are there any contradictions or logical errors in the document?
# Question: Does the narrative flow smoothly and logically throughout the document?
# Question: Are there any parts of the document that are unclear or difficult to understand?
# Personality: Emphasizes teamwork and collaboration, looking for evidence of successful collaborations and potential for future collaborations.
# Question: Are there any repeated sections or sentences in the document?
# Question: Are there any contradictions or logical errors in the document?
# Question: Does the narrative flow smoothly and logically throughout the document?
# Question: Are there any parts of the document that are unclear or difficult to understand?
# ...

# %%
print(model_answers)
# Out:
# ['Yes, some sections and sentences are repeated across different parts of the document. Here\'s a summary:\n\n1. **Travel and subsistence costs:** This section appears multiple times for each consortium partner (DEM, LUKE, DOGA, AECRANI). The specifics like local travel cost per trip or conference fee differ between partners.\n\n2. **Equipment costs:** Equipment-related expenses are mentioned in various sections with different items and costs associated with them - such as camera traps for DOGA\'s section (€8000).\n\n3. **Participatory process organization:** This is discussed under "Other goods, works, and services" category which is consistent across all partners but the specifics of what participatory processes include vary.\n\n4. **Remainig purchase costs (<15% of personnel costs):** This expense appears in each partner\'s section with a fixed amount (€1600 for DEM, €29400 for AECRANI).\n\n5. **Total Cost:** The total cost figures are repeated at the end under "Cost (€)" and "Jus
# ...

# %%
# for local file
from magic_doc.docconv import DocConverter, S3Config
converter = DocConverter(s3_config=None)
markdown_content, time_cost = converter.convert("/Users/lijou/Documents/Documents/Project/Notes_Docs/PreAward/exemples/Binder1.pdf", conv_timeout=300)
# Out:
# 2024-07-15 14:42:31.484 | INFO     | magic_pdf.libs.pdf_check:detect_invalid_chars:57 - cid_count: 0, text_len: 45457, cid_chars_radio: 0.0
# 2024-07-15 14:42:31.563 | INFO     | magic_doc.contrib.pdf.pdf_extractor:run:70 - stream io data is digital pdf

# %%
import ollama
from nltk import sent_tokenize, word_tokenize

def split_document(text, max_words=4000):
    sections = text.split('2. Impact')
    sections[1] = '2. Impact' + sections[1]  # Add the section title back to the second section
    sections = [section.split('3. Quality And Efficiency Of The Implementation') for section in sections]
    flattened_sections = [item for sublist in sections for item in sublist]
    if len(flattened_sections) == 3:
        flattened_sections[2] = '3. Quality And Efficiency Of The Implementation' + flattened_sections[2]

    chunks = []
    for section in flattened_sections:
        sentences = sent_tokenize(section)
        current_chunk = ''
        word_count = 0

        for sentence in sentences:
            sentence_word_count = len(word_tokenize(sentence))
            if word_count + sentence_word_count > max_words:
                chunks.append(current_chunk.strip())
                current_chunk = ''
                word_count = 0

            current_chunk += ' ' + sentence
            word_count += sentence_word_count

        if current_chunk:
            chunks.append(current_chunk.strip())

    return chunks

# Define the questions
questions = [
    "Are there any repeated sections or sentences in the document?",
    "Are there any contradictions or logical errors in the document?",
    "Does the narrative flow smoothly and logically throughout the document?",
    "Are there any parts of the document that are unclear or difficult to understand?"
]

# Define the personalities to use with InternLM2 model
personalities = [
    'Highly logical and analytical, focusing on facts and figures.',
    'Emphasizes teamwork and collaboration, looking for evidence of successful collaborations and potential for future collaborations.',
    'Forward-thinking and innovative, evaluating the grant application based on its potential to drive innovation and create new opportunities.'
]

# Initialize an empty list to store all answers from each personality for all questions
all_answers = []

document_text = markdown_content  # Assign your document content here

# Divide the document into sections or paragraphs, and assign a unique identifier to each section
sections = split_document(document_text)
section_ids = [f'Section {i+1}' for i in range(len(sections))]

# Define the section titles for context
section_titles = [
    "Introduction and Excellence",
    "Impact",
    "Quality and Efficiency of the Implementation"
]

# Iterate over each personality
for personality in personalities:
    print(f"Personality: {personality}")
    model_answers = []
    # For each question, get the answer based on this personality
    for question in questions:
        print(f"Question: {question}")
        feedback = []
        # Iterate over each section in the document
        for section_id, section, title in zip(section_ids, sections, section_titles):
            print(f"Section: {section_id}")
            messages = [
                {
                    'role': 'system',
                    'content': f'You are {personality}. Use the following section of the document, titled "{title}", to answer the question. Be sure to provide a summary of your findings at the end.\n\nDocument: {section}',
                },
                {
                    'role': 'user',
                    'content': question,
                },
            ]
            # Set options including the increased context window
            options = {
                "num_ctx": 20000  # Increase context window to 24k tokens
            }
            response = ollama.chat(model='InternLM2', messages=messages, options=options)
            # If the model finds any issues in the section, add a reference to the feedback
            if 'issue' in response['message']['content'].lower():
                feedback.append(f"{section_id}: {response['message']['content']}")
        model_answers.append('\n'.join(feedback))
    # After answering all questions with this personality, add these answers to the list of all answers
    all_answers.append(model_answers)


# Now that we have answered all questions with each model, synthesize the answers with Llama3
gemma2_synthesis = []
for i in range(len(questions)):  # For each question
    question_answers = [model_answers[i] for model_answers in all_answers]  # Get the answers to this question from all models
    synthesis_question = "Summarize and consolidate the following feedback on the document: " + ", ".join(question_answers)
    messages = [
        {
            'role': 'system',
            'content': f'You are a highly skilled synthetic analyzer. Your task is to summarize, consolidate and present in a coherent manner the feedback provided by multiple models on the document: {", ".join(question_answers)}. Ensure to highlight any common insights or discrepancies from different perspectives.',
        },
        {
            'role': 'user',
            'content': synthesis_question,
        },
    ]
    final_response = ollama.chat(model='gemma2', messages=messages)
    gemma2_synthesis.append(final_response['message']['content'])

# Print the synthesized answers once
print("Model: gemma2")
for i, answer in enumerate(gemma2_synthesis):
    print(f"Question: {questions[i]}")
    print(answer)

# Assume `document_text` is the variable holding the full text of the document
# Simplify the input and retry
final_question = "Summarize the overall feedback on the document."

messages = [
    {
        'role': 'system',
        'content': f'You are a highly skilled synthetic analyzer. Your task is to summarize, consolidate, and present in a coherent manner the feedback provided by multiple models on the document: {", ".join(gemma2_synthesis)}. Ensure to highlight any common insights or discrepancies from different perspectives.',
    },
    {
        'role': 'user',
        'content': final_question,
    },
]

# Retry with the simplified input
try:
    final_synthesis = ollama.chat(model='llama3-gradient', messages=messages)
    print(final_synthesis['message']['content'])
except Exception as e:
    print(f"Error: {e}")
# Out:
# Personality: Highly logical and analytical, focusing on facts and figures.
# Question: Are there any repeated sections or sentences in the document?
# Section: Section 1
# Section: Section 2
# Section: Section 3
# Question: Are there any contradictions or logical errors in the document?
# Section: Section 1
# Section: Section 2
# Section: Section 3
# Question: Does the narrative flow smoothly and logically throughout the document?
# Section: Section 1
# Section: Section 2
# Section: Section 3
# Question: Are there any parts of the document that are unclear or difficult to understand?
# Section: Section 1
# Section: Section 2
# Section: Section 3
# Personality: Emphasizes teamwork and collaboration, looking for evidence of successful collaborations and potential for future collaborations.
# Question: Are there any repeated sections or sentences in the document?
# Section: Section 1
# Section: Section 2
# Section: Section 3
# ...

# %%
import ollama
from nltk import sent_tokenize, word_tokenize

def split_document(text, max_words=4000):
    sections = text.split('2. Impact')
    sections[1] = '2. Impact' + sections[1]
    sections = [section.split('3. Quality And Efficiency Of The Implementation') for section in sections]
    flattened_sections = [item for sublist in sections for item in sublist]
    if len(flattened_sections) == 3:
        flattened_sections[2] = '3. Quality And Efficiency Of The Implementation' + flattened_sections[2]

    chunks = []
    for section in flattened_sections:
        sentences = sent_tokenize(section)
        current_chunk = ''
        word_count = 0

        for sentence in sentences:
            sentence_word_count = len(word_tokenize(sentence))
            if word_count + sentence_word_count > max_words:
                chunks.append(current_chunk.strip())
                current_chunk = ''
                word_count = 0

            current_chunk += ' ' + sentence
            word_count += sentence_word_count

        if current_chunk:
            chunks.append(current_chunk.strip())

    return chunks

# Define the questions
questions = [
    "Are all sections of the document clearly written and complete, with no repeated sections or sentences? Are there any contradictions, inconsistencies, or logical errors in the document?",
    "Does the narrative flow smoothly and logically throughout the document, and is the scientific and technical content accurate and robust?",
    "Does the document highlight the innovative aspects of the project, provide a clear explanation of the potential impact and benefits, and present realistic and achievable objectives with a detailed plan for implementation and management?",
    "Does the document demonstrate effective engagement with relevant stakeholders and provide examples of successful collaborations or potential for future collaborations?"
]

# Define the personalities to use with InternLM2 model
personalities = [
    'Highly logical and analytical, focusing on verifying the accuracy of data, identifying logical inconsistencies, and ensuring that arguments are supported by evidence.',
    'Emphasizes teamwork and collaboration, looking for evidence of successful collaborations, stakeholder engagement, and potential for future partnerships.',
    'Forward-thinking and innovative, evaluating the grant application based on its potential to drive innovation, create new opportunities, and generate significant impact.'
]

# Initialize an empty list to store all answers from each personality for all questions
all_answers = []

document_text = markdown_content  # Assign your document content here

# Divide the document into sections or paragraphs, and assign a unique identifier to each section
sections = split_document(document_text)
section_ids = [f'Section {i+1}' for i in range(len(sections))]

# Define the section titles for context
section_titles = [
    "Introduction and Excellence",
    "Impact",
    "Quality and Efficiency of the Implementation"
]

# Iterate over each personality
for personality in personalities:
    print(f"Personality: {personality}")
    model_answers = []
    # For each question, get the answer based on this personality
    for question in questions:
        print(f"Question: {question}")
        feedback = []
        # Iterate over each section in the document
        for section_id, section, title in zip(section_ids, sections, section_titles):
            print(f"Section: {section_titles}")
            messages = [
                {
                    'role': 'system',
                    'content': f'You are {personality}. Use the following section of the document, titled "{title}", to answer the question. Be sure to provide a summary of your findings at the end.\n\nDocument: {section}',
                },
                {
                    'role': 'user',
                    'content': question,
                },
            ]
            # Set options including the increased context window
            options = {
                "num_ctx": 20000  # Increase context window to 50k tokens
            }
            response = ollama.chat(model='InternLM2', messages=messages, options=options)
            # If the model finds any issues in the section, add a reference to the feedback
            if 'issue' in response['message']['content'].lower():
                feedback.append(f"{section_id}: {response['message']['content']}")
        model_answers.append('\n'.join(feedback))
    # After answering all questions with this personality, add these answers to the list of all answers
    all_answers.append(model_answers)

# Now that we have answered all questions with each model, synthesize the answers with gemma2
gemma2_synthesis = []
for i in range(len(questions)):  # For each question
    question_answers = [model_answers[i] for model_answers in all_answers]  # Get the answers to this question from all models
    synthesis_question = "Summarize and consolidate the following feedback on the document: " + ", ".join(question_answers)
    messages = [
        {
            'role': 'system',
            'content': f'You are a highly skilled synthetic analyzer. Your task is to summarize, consolidate and present in a coherent manner the feedback provided by multiple models on the document: {", ".join(question_answers)}. Ensure to highlight any common insights or discrepancies from different perspectives.',
        },
        {
            'role': 'user',
            'content': synthesis_question,
        },
    ]
    final_response = ollama.chat(model='gemma2', messages=messages)
    gemma2_synthesis.append(final_response['message']['content'])

# Print the synthesized answers once
print("Model: gemma2")
for i, answer in enumerate(gemma2_synthesis):
    print(f"Question: {questions[i]}")
    print(answer)

# Use llama3-gradient to summarize all the feedback from gemma2's synthesis
final_question = f"Using the provided feedback and the context of the document: '{document_text}', summarize the overall feedback on the document: " + ", ".join(gemma2_synthesis)
messages = [
    {
        'role': 'system',
        'content': f'Use the following feedback to answer the question and properly reference parts of the document when necessary: {", ".join(gemma2_synthesis)}',
    },
    {
        'role': 'user',
        'content': final_question,
    },
]
# Set options including the increased context window
options = {
    "num_ctx": 60000  # Use full advantage of the 50k token context window
}
print("Model: llama3-gradient")  # Print the name of Llama3-gradient model for this part
final_synthesis = ollama.chat(model='llama3-gradient', messages=messages, options=options)
print(final_synthesis['message']['content'])
# Out:
# Personality: Highly logical and analytical, focusing on verifying the accuracy of data, identifying logical inconsistencies, and ensuring that arguments are supported by evidence.
# Question: Are all sections of the document clearly written and complete, with no repeated sections or sentences? Are there any contradictions, inconsistencies, or logical errors in the document?
# Section: ['Introduction and Excellence', 'Impact', 'Quality and Efficiency of the Implementation']
# Section: ['Introduction and Excellence', 'Impact', 'Quality and Efficiency of the Implementation']
# Section: ['Introduction and Excellence', 'Impact', 'Quality and Efficiency of the Implementation']
# Question: Does the narrative flow smoothly and logically throughout the document, and is the scientific and technical content accurate and robust?
# Section: ['Introduction and Excellence', 'Impact', 'Quality and Efficiency of the Implementation']
# ...

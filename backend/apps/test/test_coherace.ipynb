# %%
from langchain_community.document_loaders import PyPDFLoader

# Load the PDF and extract text
loader = PyPDFLoader("/Users/lijou/Documents/Documents/Courses/Coursera/AdvancedDjango/Inro_Document.pdf")
pages = loader.load()
pdf_text = '\n'.join([page.page_content for page in pages])

# %%
import ollama


question = 'is there contradictions in the document?'

messages = [
  {
    'role': 'system',
    'content': f'Use the following document to answer the question: {pdf_text}',
  },
  {
    'role': 'user',
    'content': question,
  },
]

response = ollama.chat(model='llama3-gradient', messages=messages)
print(response['message']['content'])
# Out:
# Yes, I can see a few issues with this document. There are no specific guidelines that indicate when the document is for. The information could be applied to people of any age or experience level and it doesn't have any guidance on how long it should take to read through the entire content. There isn't even an introduction in this article. It starts off with the statement that this is a 10 minute lesson plan, which helps somewhat but I still need to know what I am supposed to be doing while I read this document. The objectives are also not clear and if there was some kind of scenario or activity at the start it would give me a better idea of how to use this as my guide. It could have been written in a more detailed and organized fashion than this. There is no clear plan for what to do while reading this document, so that makes it hard to read through without any specific ideas on where I should be in the process at each step.

# %%
import ollama

# Define the questions
questions = [
    "Are there any repeated sections or sentences in the document?",
    "Are there any contradictions or logical errors in the document?",
    "Does the narrative flow smoothly and logically throughout the document?",
    "Are there any parts of the document that are unclear or difficult to understand?"
]

# Initialize an empty list to store the answers
answers = []

# Iterate over each question
for question in questions:
    messages = [
        {
            'role': 'system',
            'content': f'Use the following document to answer the question: {pdf_text}',
        },
        {
            'role': 'user',
            'content': question,
        },
    ]
    print(messages)
    response = ollama.chat(model='llama3', messages=messages)
    # Store the answer in the answers list
    answers.append(response['message']['content'])

# Define a final question to summarize all the feedback
final_question = "Summarize the following feedback on the document: " + ", ".join(answers)

# Get the final summary from the model
messages = [
    {
        'role': 'system',
        'content': f'Use the following feedback to answer the question: {", ".join(answers)}',
    },
    {
        'role': 'user',
        'content': final_question,
    },
]
print(messages)
final_response = ollama.chat(model='llama3-gradient', messages=messages)
print(final_response['message']['content'])
# Out:
# [{'role': 'system', 'content': 'Use the following document to answer the question: Learning\tObjectives\nSetup\ta\tblog\tapplication\tin\tDjango\nConﬁgure\tthe\tdev\tserver\tto\trun\tinside\tthe\tCodio\nplatform\nRun\tdatabase\tmigrations\nCreate\tthe\t\nTag\n\t\nand\t\nPost\n\t\nmodels\nRegister\tthe\t\nTag\n\t\nand\t\nPost\n\t\nmodels\twith\tDjango\tAdmin\nCreate\ta\tpost\tthrough\tDjango\tAdmin\nConnecting\tto\tGitHub\nConnecting\tto\tGitHub\nOver\tfour\tcourses,\tyou\tare\tgoing\tto\tbuild\ta\tDjango\tapp.\tIn\torder\tto\tget\tyour\ncode\tin\tevery\tassignment,\tyou\tare\tgoing\tto\tuse\tGitHub.\tIf\tyou\tdo\tnot\tyet\nhave\tan\taccount,\tplease\t\ncreate\tone\n\t\nnow.\tWe\tare\tgoing\tto\tclone\ta\trepo\tthat\nwill\tcontain\tthe\tcode\tfor\tyour\tDjango\tapp.\nConnecting\tGitHub\tand\tCodio\nYou\tneed\tto\t\nconnect\n\t\nGitHub\tto\tyour\tCodio\taccount.\tThis\tonly\tneeds\tto\tbe\ndone\tone\ttime.\nIn\tyour\tCodio\taccount,\tclick\ton\tyour\tusername\nClick\ton\t\nApplications\nCodio\tAccount\nUnder\tGitHub,\tclick\ton\t\nConnect\taccount\nconnect\taccount\nYou\twill\tbe\tusing\tan\tSSH\tconnection,\tso\tyou\tneed\tto\tclick\ton\t\nUpload\npublic\tkey\nFork\tthe\tRepo\nGo\tto\tthe\t\nblango\n\t\nrepo.\tThis\trepo\tis\tthe\tstarting\tpoint\tfor\tyour\tblog.\nClick\ton\tthe\t“Fork”\tbutton\tin\tthe\ttop-right\tcorner.\nClick\tthe\tgreen\t“Code”\tbutton.\nCopy\tthe\tSSH\tinformation.\tIt\tshould\tlook\tsomething\tlike\tthis:\ninfo\nImportant\nIf\tyou\tdo\tnot\tuse\tthe\tSSH\tinformation,\tyou\twill\thave\tto\tprovide\tyour\nusername\tand\tPersonal\tAccess\tToken\t(PAT)\tto\tGitHub\teach\ttime\tyou\npush\tor\tpull\tfrom\tthe\trepository.\tSee\tthis\t\ndocumentation\n\t\nfor\tsetting\tup\na\tPAT\tfor\tyour\tGitHub\taccount.\nIn\tthe\tTerminal\nClone\tthe\trepo.\tYour\tcommand\tshould\tlook\tsomething\tlike\tthis:\nYou\tshould\tsee\ta\t\nblango\n\t\ndirectory\tappear\tin\tthe\tﬁle\ttree.\nYou\tare\tnow\tready\tfor\tthe\tnext\tassignment.\ngit@github.com:\n<your_github_username>\n/blango.git\ngit\n\t\nclone\tgit@github.com:\n<\nyour_github_username\n>\n/blango.git\nIntroduction\nIntroduction\nHello,\tand\twelcome\tto\tAdvanced\tDjango.\tThis\tcourse\tis\taimed\tat\tthose\twho\nhave\tsome\tunderstanding\tof\tDjango,\tand\tperhaps\thave\teven\tcompleted\ta\nproject\tor\ttwo.\nThis\tcourse\tis\tdivided\tinto\tfour\tmodules.\tWe’ll\tbe\tbuilding\tblog\tproject\tin\nDjango\tthroughout\tthe\tcourse,\tgradually\tadding\tfeatures\tto\tit.\tThe\tﬁrst\nmodule\texpands\ton\tthe\tDjango\tfundamentals.\tWe’ll\tlook\tat\tthe\tadmin\nsection,\tgeneric\tmodel\trelationships\tand\tthe\tBootstrap\tHTML\tframework,\nthen\thow\tusing\tcustom\ttemplate\ttags\tand\tﬁlters\tcan\tcut\tdown\tthe\tamount\nof\tcode\tin\tyour\ttemplates.\nModule\t2\tintroduces\t\n12-Factor\tApps\n:\tan\tinformal\tstandard\tfor\nconﬁguration\tapplications.\tWe’ll\tlook\tat\tthe\tmost\timportant\tof\tthese\tfactors\nto\tbuild\tinto\ta\tDjango\tapplication\t(conﬁguration\tand\tlogging).\tThen\twe’ll\ngive\tyou\ta\tbetter\tunderstanding\tof\tsome\tof\tDjango’s\tsecurity\tfeatures,\tthen\ndiscuss\tsome\tdiﬀerent\tways\tto\tdeploy\tyour\tapplication.\nModule\t3\tis\tabout\tperformance.\tWe’ll\tintroduce\tcaching\tand\thow\tto\tuse\tit\nwith\tyour\tDjango\tapplication,\tthen\tlook\tat\thow\tto\toptimize\tyour\tdatabase\nand\tqueries\tfor\tmore\tspeed.\nModule\t4\tis\tabout\tthe\tuser.\tYou’ll\tlearn\tabout\tcustom\tuser\tmodels,\tand\thow\nthey\tdiﬀer\tfrom\tjust\tusing\ta\tproﬁle\tobject.\tWe’ll\tthen\tlook\tat\tsome\tthird\nparty\tmodules\tto\thelp\twith\tusers\tand\tregistration:\tDjango\tRegistrations\t(to\nmake\tusers\tvalidate\ttheir\temail\taddress\tafter\tsigning\tup),\tand\tDjango\tAll\nAuth\tto\tallow\tauthentication\tvia\tthird\tparty\tservices\tor\tsocial\tnetworks.\tWe\nclose\tthe\tmodule\tby\twalking\tthrough\thow\tto\tset\tup\tauthentication\tagainst\nGoogle\tOAuth.\nCode\nAll\tcode\tis\tPEP8\tformatted\tusing\tthe\t\nBlack\n\t\ncode\tformatting\ttool\tfor\nconsi ...
# [{'role': 'system', 'content': 'Use the following document to answer the question: Learning\tObjectives\nSetup\ta\tblog\tapplication\tin\tDjango\nConﬁgure\tthe\tdev\tserver\tto\trun\tinside\tthe\tCodio\nplatform\nRun\tdatabase\tmigrations\nCreate\tthe\t\nTag\n\t\nand\t\nPost\n\t\nmodels\nRegister\tthe\t\nTag\n\t\nand\t\nPost\n\t\nmodels\twith\tDjango\tAdmin\nCreate\ta\tpost\tthrough\tDjango\tAdmin\nConnecting\tto\tGitHub\nConnecting\tto\tGitHub\nOver\tfour\tcourses,\tyou\tare\tgoing\tto\tbuild\ta\tDjango\tapp.\tIn\torder\tto\tget\tyour\ncode\tin\tevery\tassignment,\tyou\tare\tgoing\tto\tuse\tGitHub.\tIf\tyou\tdo\tnot\tyet\nhave\tan\taccount,\tplease\t\ncreate\tone\n\t\nnow.\tWe\tare\tgoing\tto\tclone\ta\trepo\tthat\nwill\tcontain\tthe\tcode\tfor\tyour\tDjango\tapp.\nConnecting\tGitHub\tand\tCodio\nYou\tneed\tto\t\nconnect\n\t\nGitHub\tto\tyour\tCodio\taccount.\tThis\tonly\tneeds\tto\tbe\ndone\tone\ttime.\nIn\tyour\tCodio\taccount,\tclick\ton\tyour\tusername\nClick\ton\t\nApplications\nCodio\tAccount\nUnder\tGitHub,\tclick\ton\t\nConnect\taccount\nconnect\taccount\nYou\twill\tbe\tusing\tan\tSSH\tconnection,\tso\tyou\tneed\tto\tclick\ton\t\nUpload\npublic\tkey\nFork\tthe\tRepo\nGo\tto\tthe\t\nblango\n\t\nrepo.\tThis\trepo\tis\tthe\tstarting\tpoint\tfor\tyour\tblog.\nClick\ton\tthe\t“Fork”\tbutton\tin\tthe\ttop-right\tcorner.\nClick\tthe\tgreen\t“Code”\tbutton.\nCopy\tthe\tSSH\tinformation.\tIt\tshould\tlook\tsomething\tlike\tthis:\ninfo\nImportant\nIf\tyou\tdo\tnot\tuse\tthe\tSSH\tinformation,\tyou\twill\thave\tto\tprovide\tyour\nusername\tand\tPersonal\tAccess\tToken\t(PAT)\tto\tGitHub\teach\ttime\tyou\npush\tor\tpull\tfrom\tthe\trepository.\tSee\tthis\t\ndocumentation\n\t\nfor\tsetting\tup\na\tPAT\tfor\tyour\tGitHub\taccount.\nIn\tthe\tTerminal\nClone\tthe\trepo.\tYour\tcommand\tshould\tlook\tsomething\tlike\tthis:\nYou\tshould\tsee\ta\t\nblango\n\t\ndirectory\tappear\tin\tthe\tﬁle\ttree.\nYou\tare\tnow\tready\tfor\tthe\tnext\tassignment.\ngit@github.com:\n<your_github_username>\n/blango.git\ngit\n\t\nclone\tgit@github.com:\n<\nyour_github_username\n>\n/blango.git\nIntroduction\nIntroduction\nHello,\tand\twelcome\tto\tAdvanced\tDjango.\tThis\tcourse\tis\taimed\tat\tthose\twho\nhave\tsome\tunderstanding\tof\tDjango,\tand\tperhaps\thave\teven\tcompleted\ta\nproject\tor\ttwo.\nThis\tcourse\tis\tdivided\tinto\tfour\tmodules.\tWe’ll\tbe\tbuilding\tblog\tproject\tin\nDjango\tthroughout\tthe\tcourse,\tgradually\tadding\tfeatures\tto\tit.\tThe\tﬁrst\nmodule\texpands\ton\tthe\tDjango\tfundamentals.\tWe’ll\tlook\tat\tthe\tadmin\nsection,\tgeneric\tmodel\trelationships\tand\tthe\tBootstrap\tHTML\tframework,\nthen\thow\tusing\tcustom\ttemplate\ttags\tand\tﬁlters\tcan\tcut\tdown\tthe\tamount\nof\tcode\tin\tyour\ttemplates.\nModule\t2\tintroduces\t\n12-Factor\tApps\n:\tan\tinformal\tstandard\tfor\nconﬁguration\tapplications.\tWe’ll\tlook\tat\tthe\tmost\timportant\tof\tthese\tfactors\nto\tbuild\tinto\ta\tDjango\tapplication\t(conﬁguration\tand\tlogging).\tThen\twe’ll\ngive\tyou\ta\tbetter\tunderstanding\tof\tsome\tof\tDjango’s\tsecurity\tfeatures,\tthen\ndiscuss\tsome\tdiﬀerent\tways\tto\tdeploy\tyour\tapplication.\nModule\t3\tis\tabout\tperformance.\tWe’ll\tintroduce\tcaching\tand\thow\tto\tuse\tit\nwith\tyour\tDjango\tapplication,\tthen\tlook\tat\thow\tto\toptimize\tyour\tdatabase\nand\tqueries\tfor\tmore\tspeed.\nModule\t4\tis\tabout\tthe\tuser.\tYou’ll\tlearn\tabout\tcustom\tuser\tmodels,\tand\thow\nthey\tdiﬀer\tfrom\tjust\tusing\ta\tproﬁle\tobject.\tWe’ll\tthen\tlook\tat\tsome\tthird\nparty\tmodules\tto\thelp\twith\tusers\tand\tregistration:\tDjango\tRegistrations\t(to\nmake\tusers\tvalidate\ttheir\temail\taddress\tafter\tsigning\tup),\tand\tDjango\tAll\nAuth\tto\tallow\tauthentication\tvia\tthird\tparty\tservices\tor\tsocial\tnetworks.\tWe\nclose\tthe\tmodule\tby\twalking\tthrough\thow\tto\tset\tup\tauthentication\tagainst\nGoogle\tOAuth.\nCode\nAll\tcode\tis\tPEP8\tformatted\tusing\tthe\t\nBlack\n\t\ncode\tformatting\ttool\tfor\nconsi ...
# [{'role': 'system', 'content': 'Use the following document to answer the question: Learning\tObjectives\nSetup\ta\tblog\tapplication\tin\tDjango\nConﬁgure\tthe\tdev\tserver\tto\trun\tinside\tthe\tCodio\nplatform\nRun\tdatabase\tmigrations\nCreate\tthe\t\nTag\n\t\nand\t\nPost\n\t\nmodels\nRegister\tthe\t\nTag\n\t\nand\t\nPost\n\t\nmodels\twith\tDjango\tAdmin\nCreate\ta\tpost\tthrough\tDjango\tAdmin\nConnecting\tto\tGitHub\nConnecting\tto\tGitHub\nOver\tfour\tcourses,\tyou\tare\tgoing\tto\tbuild\ta\tDjango\tapp.\tIn\torder\tto\tget\tyour\ncode\tin\tevery\tassignment,\tyou\tare\tgoing\tto\tuse\tGitHub.\tIf\tyou\tdo\tnot\tyet\nhave\tan\taccount,\tplease\t\ncreate\tone\n\t\nnow.\tWe\tare\tgoing\tto\tclone\ta\trepo\tthat\nwill\tcontain\tthe\tcode\tfor\tyour\tDjango\tapp.\nConnecting\tGitHub\tand\tCodio\nYou\tneed\tto\t\nconnect\n\t\nGitHub\tto\tyour\tCodio\taccount.\tThis\tonly\tneeds\tto\tbe\ndone\tone\ttime.\nIn\tyour\tCodio\taccount,\tclick\ton\tyour\tusername\nClick\ton\t\nApplications\nCodio\tAccount\nUnder\tGitHub,\tclick\ton\t\nConnect\taccount\nconnect\taccount\nYou\twill\tbe\tusing\tan\tSSH\tconnection,\tso\tyou\tneed\tto\tclick\ton\t\nUpload\npublic\tkey\nFork\tthe\tRepo\nGo\tto\tthe\t\nblango\n\t\nrepo.\tThis\trepo\tis\tthe\tstarting\tpoint\tfor\tyour\tblog.\nClick\ton\tthe\t“Fork”\tbutton\tin\tthe\ttop-right\tcorner.\nClick\tthe\tgreen\t“Code”\tbutton.\nCopy\tthe\tSSH\tinformation.\tIt\tshould\tlook\tsomething\tlike\tthis:\ninfo\nImportant\nIf\tyou\tdo\tnot\tuse\tthe\tSSH\tinformation,\tyou\twill\thave\tto\tprovide\tyour\nusername\tand\tPersonal\tAccess\tToken\t(PAT)\tto\tGitHub\teach\ttime\tyou\npush\tor\tpull\tfrom\tthe\trepository.\tSee\tthis\t\ndocumentation\n\t\nfor\tsetting\tup\na\tPAT\tfor\tyour\tGitHub\taccount.\nIn\tthe\tTerminal\nClone\tthe\trepo.\tYour\tcommand\tshould\tlook\tsomething\tlike\tthis:\nYou\tshould\tsee\ta\t\nblango\n\t\ndirectory\tappear\tin\tthe\tﬁle\ttree.\nYou\tare\tnow\tready\tfor\tthe\tnext\tassignment.\ngit@github.com:\n<your_github_username>\n/blango.git\ngit\n\t\nclone\tgit@github.com:\n<\nyour_github_username\n>\n/blango.git\nIntroduction\nIntroduction\nHello,\tand\twelcome\tto\tAdvanced\tDjango.\tThis\tcourse\tis\taimed\tat\tthose\twho\nhave\tsome\tunderstanding\tof\tDjango,\tand\tperhaps\thave\teven\tcompleted\ta\nproject\tor\ttwo.\nThis\tcourse\tis\tdivided\tinto\tfour\tmodules.\tWe’ll\tbe\tbuilding\tblog\tproject\tin\nDjango\tthroughout\tthe\tcourse,\tgradually\tadding\tfeatures\tto\tit.\tThe\tﬁrst\nmodule\texpands\ton\tthe\tDjango\tfundamentals.\tWe’ll\tlook\tat\tthe\tadmin\nsection,\tgeneric\tmodel\trelationships\tand\tthe\tBootstrap\tHTML\tframework,\nthen\thow\tusing\tcustom\ttemplate\ttags\tand\tﬁlters\tcan\tcut\tdown\tthe\tamount\nof\tcode\tin\tyour\ttemplates.\nModule\t2\tintroduces\t\n12-Factor\tApps\n:\tan\tinformal\tstandard\tfor\nconﬁguration\tapplications.\tWe’ll\tlook\tat\tthe\tmost\timportant\tof\tthese\tfactors\nto\tbuild\tinto\ta\tDjango\tapplication\t(conﬁguration\tand\tlogging).\tThen\twe’ll\ngive\tyou\ta\tbetter\tunderstanding\tof\tsome\tof\tDjango’s\tsecurity\tfeatures,\tthen\ndiscuss\tsome\tdiﬀerent\tways\tto\tdeploy\tyour\tapplication.\nModule\t3\tis\tabout\tperformance.\tWe’ll\tintroduce\tcaching\tand\thow\tto\tuse\tit\nwith\tyour\tDjango\tapplication,\tthen\tlook\tat\thow\tto\toptimize\tyour\tdatabase\nand\tqueries\tfor\tmore\tspeed.\nModule\t4\tis\tabout\tthe\tuser.\tYou’ll\tlearn\tabout\tcustom\tuser\tmodels,\tand\thow\nthey\tdiﬀer\tfrom\tjust\tusing\ta\tproﬁle\tobject.\tWe’ll\tthen\tlook\tat\tsome\tthird\nparty\tmodules\tto\thelp\twith\tusers\tand\tregistration:\tDjango\tRegistrations\t(to\nmake\tusers\tvalidate\ttheir\temail\taddress\tafter\tsigning\tup),\tand\tDjango\tAll\nAuth\tto\tallow\tauthentication\tvia\tthird\tparty\tservices\tor\tsocial\tnetworks.\tWe\nclose\tthe\tmodule\tby\twalking\tthrough\thow\tto\tset\tup\tauthentication\tagainst\nGoogle\tOAuth.\nCode\nAll\tcode\tis\tPEP8\tformatted\tusing\tthe\t\nBlack\n\t\ncode\tformatting\ttool\tfor\nconsi ...
# [{'role': 'system', 'content': 'Use the following document to answer the question: Learning\tObjectives\nSetup\ta\tblog\tapplication\tin\tDjango\nConﬁgure\tthe\tdev\tserver\tto\trun\tinside\tthe\tCodio\nplatform\nRun\tdatabase\tmigrations\nCreate\tthe\t\nTag\n\t\nand\t\nPost\n\t\nmodels\nRegister\tthe\t\nTag\n\t\nand\t\nPost\n\t\nmodels\twith\tDjango\tAdmin\nCreate\ta\tpost\tthrough\tDjango\tAdmin\nConnecting\tto\tGitHub\nConnecting\tto\tGitHub\nOver\tfour\tcourses,\tyou\tare\tgoing\tto\tbuild\ta\tDjango\tapp.\tIn\torder\tto\tget\tyour\ncode\tin\tevery\tassignment,\tyou\tare\tgoing\tto\tuse\tGitHub.\tIf\tyou\tdo\tnot\tyet\nhave\tan\taccount,\tplease\t\ncreate\tone\n\t\nnow.\tWe\tare\tgoing\tto\tclone\ta\trepo\tthat\nwill\tcontain\tthe\tcode\tfor\tyour\tDjango\tapp.\nConnecting\tGitHub\tand\tCodio\nYou\tneed\tto\t\nconnect\n\t\nGitHub\tto\tyour\tCodio\taccount.\tThis\tonly\tneeds\tto\tbe\ndone\tone\ttime.\nIn\tyour\tCodio\taccount,\tclick\ton\tyour\tusername\nClick\ton\t\nApplications\nCodio\tAccount\nUnder\tGitHub,\tclick\ton\t\nConnect\taccount\nconnect\taccount\nYou\twill\tbe\tusing\tan\tSSH\tconnection,\tso\tyou\tneed\tto\tclick\ton\t\nUpload\npublic\tkey\nFork\tthe\tRepo\nGo\tto\tthe\t\nblango\n\t\nrepo.\tThis\trepo\tis\tthe\tstarting\tpoint\tfor\tyour\tblog.\nClick\ton\tthe\t“Fork”\tbutton\tin\tthe\ttop-right\tcorner.\nClick\tthe\tgreen\t“Code”\tbutton.\nCopy\tthe\tSSH\tinformation.\tIt\tshould\tlook\tsomething\tlike\tthis:\ninfo\nImportant\nIf\tyou\tdo\tnot\tuse\tthe\tSSH\tinformation,\tyou\twill\thave\tto\tprovide\tyour\nusername\tand\tPersonal\tAccess\tToken\t(PAT)\tto\tGitHub\teach\ttime\tyou\npush\tor\tpull\tfrom\tthe\trepository.\tSee\tthis\t\ndocumentation\n\t\nfor\tsetting\tup\na\tPAT\tfor\tyour\tGitHub\taccount.\nIn\tthe\tTerminal\nClone\tthe\trepo.\tYour\tcommand\tshould\tlook\tsomething\tlike\tthis:\nYou\tshould\tsee\ta\t\nblango\n\t\ndirectory\tappear\tin\tthe\tﬁle\ttree.\nYou\tare\tnow\tready\tfor\tthe\tnext\tassignment.\ngit@github.com:\n<your_github_username>\n/blango.git\ngit\n\t\nclone\tgit@github.com:\n<\nyour_github_username\n>\n/blango.git\nIntroduction\nIntroduction\nHello,\tand\twelcome\tto\tAdvanced\tDjango.\tThis\tcourse\tis\taimed\tat\tthose\twho\nhave\tsome\tunderstanding\tof\tDjango,\tand\tperhaps\thave\teven\tcompleted\ta\nproject\tor\ttwo.\nThis\tcourse\tis\tdivided\tinto\tfour\tmodules.\tWe’ll\tbe\tbuilding\tblog\tproject\tin\nDjango\tthroughout\tthe\tcourse,\tgradually\tadding\tfeatures\tto\tit.\tThe\tﬁrst\nmodule\texpands\ton\tthe\tDjango\tfundamentals.\tWe’ll\tlook\tat\tthe\tadmin\nsection,\tgeneric\tmodel\trelationships\tand\tthe\tBootstrap\tHTML\tframework,\nthen\thow\tusing\tcustom\ttemplate\ttags\tand\tﬁlters\tcan\tcut\tdown\tthe\tamount\nof\tcode\tin\tyour\ttemplates.\nModule\t2\tintroduces\t\n12-Factor\tApps\n:\tan\tinformal\tstandard\tfor\nconﬁguration\tapplications.\tWe’ll\tlook\tat\tthe\tmost\timportant\tof\tthese\tfactors\nto\tbuild\tinto\ta\tDjango\tapplication\t(conﬁguration\tand\tlogging).\tThen\twe’ll\ngive\tyou\ta\tbetter\tunderstanding\tof\tsome\tof\tDjango’s\tsecurity\tfeatures,\tthen\ndiscuss\tsome\tdiﬀerent\tways\tto\tdeploy\tyour\tapplication.\nModule\t3\tis\tabout\tperformance.\tWe’ll\tintroduce\tcaching\tand\thow\tto\tuse\tit\nwith\tyour\tDjango\tapplication,\tthen\tlook\tat\thow\tto\toptimize\tyour\tdatabase\nand\tqueries\tfor\tmore\tspeed.\nModule\t4\tis\tabout\tthe\tuser.\tYou’ll\tlearn\tabout\tcustom\tuser\tmodels,\tand\thow\nthey\tdiﬀer\tfrom\tjust\tusing\ta\tproﬁle\tobject.\tWe’ll\tthen\tlook\tat\tsome\tthird\nparty\tmodules\tto\thelp\twith\tusers\tand\tregistration:\tDjango\tRegistrations\t(to\nmake\tusers\tvalidate\ttheir\temail\taddress\tafter\tsigning\tup),\tand\tDjango\tAll\nAuth\tto\tallow\tauthentication\tvia\tthird\tparty\tservices\tor\tsocial\tnetworks.\tWe\nclose\tthe\tmodule\tby\twalking\tthrough\thow\tto\tset\tup\tauthentication\tagainst\nGoogle\tOAuth.\nCode\nAll\tcode\tis\tPEP8\tformatted\tusing\tthe\t\nBlack\n\t\ncode\tformatting\ttool\tfor\nconsi ...
# [{'role': 'system', 'content': 'Use the following feedback to answer the question: After analyzing the document, I found that there are no repeated sections or sentences. The document appears to be a single, cohesive piece of text that presents information about Django\'s admin site and how to customize it., After reviewing the document, I did not find any significant contradictions or logical errors. The text appears to be a clear and concise introduction to Django\'s admin site, covering topics such as registering models, customizing the admin site, and using the `admin.site` object.\n\nHowever, there are a few minor points that could be clarified for readers:\n\n1. In the section "What is `admin.site`?", it would be helpful to provide more context about what an admin site is and why Django provides this feature.\n2. The text assumes that readers have a basic understanding of Django and its project structure. Readers who are new to Django might find it helpful if the document provided more background information or tutorials on how to set up a Django project.\n3. The section "Models List" mentions that the `created_at` and `modified_at` fields do not show up in the field list, but this is not explained further. It would be helpful to provide more context about why these fields are automatically populated.\n\nOverall, the document appears to be well-organized and easy to follow, with clear examples of how to use Django\'s admin site. However, providing additional background information or clarification on certain points could make it more accessible to readers who are new to Django., The narrative in this document generally flows smoothly and logically, but there are a few areas where it could be improved:\n\n1. The introduction to `admin.site` is abrupt and lacks context. It would be helpful to provide more background on what the admin site is and why it\'s important before diving into the details of how to use it.\n2. The transition from explaining the basic registration of a model to creating a custom `ModelAdmin` subclass could be smoother. The text jumps abruptly from explaining the simple case to introducing the concept of a custom `ModelAdmin` subclass without much warning or explanation.\n3. Some of the sections, such as the one on "Launching the Blog" and "Models List", feel like they\'re simply providing step-by-step instructions rather than contributing meaningfully to the narrative flow. It might be helpful to integrate these sections more closely into the main narrative thread.\n\nOverall, however, the document is well-organized and easy to follow, and the author does a good job of breaking down complex concepts into manageable chunks., After reviewing the document, I didn\'t find any parts that appear to be unclear or difficult to understand. The language used is generally straightforward and easy to follow. The explanations provided for concepts like `admin.site`, `ModelAdmin`, and `prepopulated_fields` are concise and helpful.\n\nThe examples given, such as registering a model with the admin site and customizing the display of a model in the admin interface, are also well-explained and should be easy to follow. The code snippets provided are short and simple, making it easy to understand how to implement the concepts discussed.\n\nOverall, the document appears to be well-organized and easy to understand, with clear explanations and concise examples.'}, {'role': 'user', 'content': 'Summarize the following feedback on the document: After analyzing the document, I found that there are no repeated sections or sentences. The document appears to be a single, cohesive piece of text that presents information about Django\'s admin site and how to customize it., After reviewing the document, I did not find any significant contradictions or logical errors. The text appears to be a clear and concise introduction to Django\'s admin site, covering topics such as registering models, customizing the admin site, and using the  ...
# This feedback on a Django documentation is as follows:
#
# The reviewer has positive comments about the organization of the content in that section. The section "What is `admin. site`?" should provide more context for readers who are new to Django, and the sections "Launching the Blog" and "Models List" could be integrated into the main narrative. There are no significant contradictions or logical errors in the text. The text appears to be a single cohesive piece of information that presents details on how to customize an admin site. The text could be more accessible if it provided some background about Django and its project structure as well as why certain fields such as `created_ at` and `modified_at` are automatically populated.

# %%
import ollama

# Define the questions
questions = [
    "Are there any repeated sections or sentences in the document?",
    "Are there any contradictions or logical errors in the document?",
    "Does the narrative flow smoothly and logically throughout the document?",
    "Are there any parts of the document that are unclear or difficult to understand?"
]

# Define the language models to use
models = ['mistral', 'phi3', 'qwen2']

# Initialize an empty list to store all answers from each model for each question
all_answers = []

# Iterate over each question
for question in questions:
    print(f"Question: {question}")  # Print the original text of the question
    question_answers = []  # Reset the list of answers for this question
    # For each language model, get the answer for this question
    for model in models:
        print(f"Model: {model}")  # Print the name of the current model
        messages = [
            {
                'role': 'system',
                'content': f'Use the following document to answer the question: {pdf_text}',
            },
            {
                'role': 'user',
                'content': question,
            },
        ]
        # print(messages)
        response = ollama.chat(model=model, messages=messages)
        print(response)
        # Store the answer in the list of answers for this question
        question_answers.append(response['message']['content'])
    # Synthesize the answers from all models for this question using Llama3
    synthesis_question = "Summarize the following feedback on the document: " + ", ".join(question_answers)
    messages = [
        {
            'role': 'system',
            'content': f'Use the following feedback to answer the question: {", ".join(question_answers)}',
        },
        {
            'role': 'user',
            'content': synthesis_question,
        },
    ]
    print("Model: llama3")  # Print the name of Llama3 model for this part
    #print(messages)
    final_response = ollama.chat(model='llama3', messages=messages)
    print(final_response)
    # Store the synthesized answer in the list of all answers
    all_answers.append(final_response['message']['content'])

# Define a final question to summarize all the feedback from Llama3's synthesis
final_question = "Summarize the overall feedback on the document: " + ", ".join(all_answers)

# Get the final summary from the model Llama3-gradient
messages = [
    {
        'role': 'system',
        'content': f'Use the following feedback to answer the question: {", ".join(all_answers)}',
    },
    {
        'role': 'user',
        'content': final_question,
    },
]
print("Model: llama3-gradient")  # Print the name of Llama3-gradient model for this part
#print(messages)
final_synthesis = ollama.chat(model='llama3-gradient', messages=messages)
print(final_synthesis['message']['content'])
# Out:
# Question: Are there any repeated sections or sentences in the document?
# Model: mistral
# {'model': 'mistral', 'created_at': '2024-06-21T12:20:11.346503Z', 'message': {'role': 'assistant', 'content': " Yes, there are some repeated sections and sentences in the document. Here's a summary:\n\n1. Launching the Blog (twice)\n2. Models List\n3. Challenge and Solution for changing PostAdmin\n4. Pushing to GitHub\n\nBy consolidating these repeated sections, the text can be made more concise and easier to read."}, 'done_reason': 'stop', 'done': True, 'total_duration': 2938699667, 'load_duration': 5214375, 'prompt_eval_duration': 180068000, 'eval_count': 79, 'eval_duration': 2730893000}
# Model: phi3
# {'model': 'phi3', 'created_at': '2024-06-21T12:20:24.330524Z', 'message': {'role': 'assistant', 'content': ' Yes, some parts of the provided text appear to be repeated. Here are a few examples:\n\n1. "list_display = (\'slug\', \'published_at\')" and "In admin.py, PostAdmin(admin.ModelAdmin):\t\t\t\t\n list_display = ( \'slug\', \'publishedited_at\' )" - these lines are repeated twice in the document without any variation or additional information provided. \n\n2. The phrase "Click on... to go..." is used multiple times, such as when instructing how to navigate the admin page and access the Posts list view. To avoid repetition and maintain clarity, it would be beneficial to vary these instructions slightly each time they appear in the document or provide more context for each step.\n Written by: Dr. Samuel Johnson\nAssistant created by: GPT-3 (OpenAI)'}, 'done_reason': 'stop', 'done': True, 'total_duration': 12979937459, 'load_duration': 3856015125, 'prompt_eval_count': 1756, 'prompt_eval_duration': 3692675000, 'eval_count': 188, 'eval_duration': 5397669000}
# Model: qwen2
# {'model': 'qwen2', 'created_at': '2024-06-21T12:20:40.597252Z', 'message': {'role': 'assistant', 'content': "Upon reviewing the provided text, there are no explicit instances of repeated sections or sentences. Each part of the documentation covers distinct topics related to Django web development:\n\n- Setting up and using Django's admin site for model registration.\n- Customizing Django ModelAdmin classes for more tailored admin interfaces.\n- Launching a blog application with created models (Post and Tag).\n- Interacting with the Django admin interface to create content like posts and tags.\n\nWhile there are some repetitive instructions (like logging into the Django admin), these do not constitute repetition in terms of content or information. Each step builds upon the last, adding depth but not duplicating existing knowledge within the document itself."}, 'done_reason': 'stop', 'done': True, 'total_duration': 16258707834, 'load_duration': 6788917292, 'prompt_eval_count': 1687, 'prompt_eval_duration': 4922447000, 'eval_count': 134, 'eval_duration': 4504382000}
# Model: llama3
# {'model': 'llama3', 'created_at': '2024-06-21T12:20:54.577293Z', 'message': {'role': 'assistant', 'content': 'The feedback states that the provided text contains repeated sections and sentences. Specifically:\n\n1. The "Launching the Blog" section is duplicated.\n2. A list of models is mentioned twice.\n3. There are two instances discussing changing PostAdmin and pushing to GitHub.\n4. The code snippet `list_display = (\'slug\', \'published_at\')` appears twice without variation or additional information.\n\nThe feedback also notes that some instructions, such as "Click on... to go...", are repeated throughout the document. To improve clarity and concision, it is suggested to consolidate these repeated sections and vary instructions slightly each time they appear in the document.'}, 'done_reason': 'stop', 'done': True, 'total_duration': 13978155125, 'load_duration': 7455194667, 'prompt_eval_count': 762, 'prompt_eval_duration': 2357657000, 'eval_count': 128, 'eval_duration': 4158187000}
# Question: Are there any contradictions or logical errors in the document?
# Model: mistral
# {'model': 'mistral', 'created_at': '2024-06-21T12:21:12.403653Z', 'message': {'role': 'assistant', 'content': " There are no apparent contradictions or logical errors in the document. The document provides clear instructions on how to use Django's ModelAdmin and admin.site.register to create an admin interface for a custom model, in this case, a Post model for a blog application. It also explains the use of list_display, prepopulated_fields, and other options available in the Django ModelAdmin documentation. The document also guides the user on how to push their changes to GitHub. Overall, it seems well-organized and easy to follow."}, 'done_reason': 'stop', 'done': True, 'total_duration': 17822022500, 'load_duration': 8640005583, 'prompt_eval_count': 1704, 'prompt_eval_duration': 5334108000, 'eval_count': 114, 'eval_duration': 3824984000}
# Model: phi3
# {'model': 'phi3', 'created_at': '2024-06-21T12:21:25.957994Z', 'message': {'role': 'assistant', 'content': ' No, there are no contradictions or logical errors found in the provided document. It presents a clear and concise guide on setting up Django Admin for managing Post instances within an application named "Blog". The instructions given follow logically from one to another, outlining steps that a developer would reasonably expect while configuring a Django admin interface.\n\n\nThe key points covered in the document are:\n- Setting up and using Django Admin by registering models with their respective ModelAdmin classes.\n- Defining which fields should be editable or excluded from editing within the forms.\n- Customizing list_display to include specific fields on model instance lists, such as \'slug\' for a Post model.\n- Creating a new ModelAdmin class and using prepopulated_fields option to set up automatic slug generation based on title.\n\nEach step is clearly explained with appropriate examples, which makes it easy for developers or users learning about Django Admin to follow along without encountering logical errors.'}, 'done_reason': 'stop', 'done': True, 'total_duration': 13550449791, 'load_duration': 3860071041, 'prompt_eval_count': 1757, 'prompt_eval_duration': 3649598000, 'eval_count': 208, 'eval_duration': 6013379000}
# Model: qwen2
# {'model': 'qwen2', 'created_at': '2024-06-21T12:21:55.230763Z', 'message': {'role': 'assistant', 'content': 'The document on Django admin is generally well-written and informative, but upon a careful review, here are some minor points that may be considered for clarification to avoid potential confusion:\n\n1. **Formatting of URLs**: The author uses HTML `<code>` tags around URLs to denote they should be read as code. However, there\'s inconsistency in how these are used throughout the document:\n   - Some URLs like `admin.site.urls` have proper formatting using the `<code>` tag.\n   - Other examples like `urls.py` and `admin/` do not use `<code>`. For consistency, either all or none should include `<code>` tags around code elements.\n\n2. **Consistency in Code Syntax Highlighting**: The document uses different syntax highlighting styles for code blocks across the text:\n   - In some parts (like `class PostAdmin(admin.ModelAdmin):`), it uses monospace font with a block formatting.\n   - In others, like `from django.contrib import admin`, it uses a link to external documentation but does not highlight or format the code. \n   - For consistency in terms of how code is highlighted and formatted, either all should follow one style or none at all.\n\n3. **Use of \'info\' Tag**: The \'info\' tag is used for providing inline information. It works well where it\'s used like "View in External Tab". However, some other points could benefit from clearer labels:\n   - For example, when referring to the \'Add Post\' button or the list display options in Django Admin, these could be labeled with similar informative tags.\n\n4. **Language and Phrasing**: The language is mostly clear and professional, but there are a few instances that might need clarification for beginners:\n   - In the section "Models List", the term "the model instance\'s id/pk (primary key) doesn\'t show" might confuse someone not familiar with primary keys in databases. A more beginner-friendly explanation could be provided.\n   - Similarly, explaining why certain fields like `created_at` and `modified_at` do not appear when creating a new post could help clarify this part.\n\n5. **Clarity of \'Challenge\' Section**: The challenge section is well-presented with clear instructions on how to proceed using the GitHub link provided for editing `admin.py`. However, it assumes knowledge about making changes in code and pushing to GitHub, which might not be clear to a beginner audience without additional context or an example.\n\nBy addressing these points, the document could be made even more helpful and user-friendly for those learning Django and its administration features.'}, 'done_reason': 'stop', 'done': True, 'total_duration': 29270325709, 'load_duration': 6813368167, 'prompt_eval_count': 1687, 'prompt_eval_duration': 4848392000, 'eval_count': 518, 'eval_duration': 17553118000}
# Model: llama3
# {'model': 'llama3', 'created_at': '2024-06-21T12:22:16.260651Z', 'message': {'role': 'assistant', 'content': "The feedback on the document is overwhelmingly positive, stating that there are no contradictions or logical errors in the document. The document provides clear instructions on how to use Django's ModelAdmin and admin.site.register to create an admin interface for a custom model, as well as other options available in the Django ModelAdmin documentation.\n\nHowever, the reviewer also pointed out some minor areas for improvement:\n\n1. Formatting of URLs: There is inconsistency in how URL codes are formatted throughout the document.\n2. Consistency in Code Syntax Highlighting: The document uses different syntax highlighting styles for code blocks across the text.\n3. Use of 'info' Tag: Some points could benefit from clearer labels, such as using informative tags to label certain parts.\n4. Language and Phrasing: There are a few instances where the language may be unclear or confusing for beginners.\n5. Clarity of 'Challenge' Section: The challenge section assumes knowledge about making changes in code and pushing to GitHub, which may not be clear to beginner audiences.\n\nOverall, the document is considered well-written and informative, but with some minor areas for improvement to make it even more helpful and user-friendly for those learning Django and its administration features."}, 'done_reason': 'stop', 'done': True, 'total_duration': 21027148458, 'load_duration': 7187279250, 'prompt_eval_count': 1642, 'prompt_eval_duration': 5160685000, 'eval_count': 239, 'eval_duration': 8674010000}
# Question: Does the narrative flow smoothly and logically throughout the document?
# Model: mistral
# {'model': 'mistral', 'created_at': '2024-06-21T12:22:41.476919Z', 'message': {'role': 'assistant', 'content': " Yes, the narrative flows smoothly and logically throughout the document. The author provides clear explanations and instructions for creating a model using Django's ModelAdmin, registering it with the admin site, and interacting with the Django Admin interface to create and manage posts in the application. The document also includes challenges and solutions to encourage the reader to apply their knowledge by making changes to the provided code. Overall, the document is well-organized and easy to follow for beginners learning how to use Django's ModelAdmin and Django Admin interface.\n\nFormative Assessment 1:\nIn the provided code for PostAdmin, what does prepopulated\\_fields do? What are its values? How is it used in the PostAdmin class?\n\nFormative Assessment 2:\nIn the provided code for PostAdmin, what does list\\_display do? What are its values? How is it used in the PostAdmin class?\n\nSolution to Formative Assessment 1:\nprepopulated\\_fields is a dictionary that sets the slug field value automatically based on the title field value. In other words, when a new post instance is created, the slug will be set according to the provided title.\n\nSolution to Formative Assessment 2:\nlist\\_display is a tuple that specifies which fields will be displayed in the Post list view in the Django Admin interface. In this case, it's set to ('slug', 'published_at') to show the slug and published_at fields in the list view of posts."}, 'done_reason': 'stop', 'done': True, 'total_duration': 25214283416, 'load_duration': 8640277541, 'prompt_eval_count': 1704, 'prompt_eval_duration': 5331344000, 'eval_count': 330, 'eval_duration': 11212964000}
# Model: phi3
# {'model': 'phi3', 'created_at': '2024-06-21T12:22:52.132143Z', 'message': {'role': 'assistant', 'content': " Yes, the narrative flows smoothly and logically throughout the document. It starts by introducing Django Admin, its purpose, and how it can be used in a blog project. The document then proceeds to detail steps for setting up and using the PostAdmin class with an example. Each section builds upon the previous information, making the narrative progressive and easy to follow. Finally, it concludes by suggesting pushing changes to GitHub and hinting at future content about Django' Author Generator, maintaining logical continuity."}, 'done_reason': 'stop', 'done': True, 'total_duration': 10653837792, 'load_duration': 3864282084, 'prompt_eval_count': 1759, 'prompt_eval_duration': 3641620000, 'eval_count': 108, 'eval_duration': 3114170000}
# Model: qwen2
# {'model': 'qwen2', 'created_at': '2024-06-21T12:23:10.976984Z', 'message': {'role': 'assistant', 'content': 'The narrative does indeed flow smoothly and logically throughout the document. It starts with an introduction to Django, moves through setting up a blog application step-by-step including models, views, forms, templates, and then onto discussing the admin site for managing content.\n\nIt provides clear explanations, code snippets, instructions, and even includes interactive steps like launching the test server and navigating the admin interface. The transitions between topics are well managed with bullet points summarizing previous sections and introducing new ones. \n\nThe document also incorporates links to more detailed documentation when more information is needed on specific subjects (like customizing Django Model Admin). \n\nIt breaks down complex concepts into manageable parts suitable for learning, with examples showing how things work in code and what the expected results are. There\'s even a "Challenge" section that encourages readers to apply what they\'ve learned.\n\nSo yes, the structure allows the information to be presented coherently, enabling readers to follow along easily without confusion or gaps in their understanding. The flow of knowledge feels well-designed for educational material like this.'}, 'done_reason': 'stop', 'done': True, 'total_duration': 18841585791, 'load_duration': 6832214875, 'prompt_eval_count': 1687, 'prompt_eval_duration': 4851619000, 'eval_count': 210, 'eval_duration': 7092967000}
# Model: llama3
# {'model': 'llama3', 'created_at': '2024-06-21T12:23:28.22382Z', 'message': {'role': 'assistant', 'content': "The feedback is overwhelmingly positive, praising the document's narrative flow, clarity, and organization. Key points include:\n\n* The document flows smoothly and logically throughout, making it easy to follow.\n* Clear explanations and instructions are provided for creating a model using Django's ModelAdmin, registering it with the admin site, and interacting with the Django Admin interface.\n* Challenges and solutions are included to encourage readers to apply their knowledge by making changes to the provided code.\n* The document is well-organized, breaking down complex concepts into manageable parts suitable for learning.\n* Interactive steps, such as launching a test server and navigating the admin interface, are included to engage readers.\n* Links to more detailed documentation are provided when needed, allowing readers to dive deeper into specific topics.\n\nOverall, the feedback suggests that the document is well-suited for beginners learning how to use Django's ModelAdmin and Django Admin interface."}, 'done_reason': 'stop', 'done': True, 'total_duration': 17243609250, 'load_duration': 7206400125, 'prompt_eval_count': 1230, 'prompt_eval_duration': 3831123000, 'eval_count': 179, 'eval_duration': 6197533000}
# Question: Are there any parts of the document that are unclear or difficult to understand?
# Model: mistral
# {'model': 'mistral', 'created_at': '2024-06-21T12:23:46.29081Z', 'message': {'role': 'assistant', 'content': ' The document is clear and easy to understand for someone with basic knowledge of Django. However, if you\'re new to Django, some terms like "model", "admin site", and "terminal" might require a bit more explanation.\n\nFor the challenge part, it would be helpful if there was a brief explanation or link on how to use prepopulated_fields in the PostAdmin class. Also, mentioning that list_display should replace (or work along with) list_display_links for clarity could be beneficial.\n\nOverall, good job on making the content accessible and easy to follow!'}, 'done_reason': 'stop', 'done': True, 'total_duration': 18062452583, 'load_duration': 8391129375, 'prompt_eval_count': 1708, 'prompt_eval_duration': 5332831000, 'eval_count': 129, 'eval_duration': 4324528000}
# Model: phi3
# {'model': 'phi3', 'created_at': '2024-06-21T12:24:08.015469Z', 'message': {'role': 'assistant', 'content': ' If you have any specific sections in the provided document that appear unclear or difficult to comprehend, please point them out. The goal is for me to offer additional clarification on those areas and ensure a better understanding overall.\n\nFor example:\n\n1. In the context of using the Django Model Admin interface (the PostAdmin class), it\'s mentioned how to include fields that are not editable by default, like \'id\'. However, the explanation could be more detailed about why this is done and its implications on saving model instances. A clearer elaboration would help clarify the concept:\n\n```python\nif exclude or (\'id\',):  # This condition checks if the field should be included in the form or not based on the \'exclude\' parameter passed to list_display or a direct inclusion of \'id\'.\n    pass  # When you do this, it ensures that users cannot change the primary key (id) directly through the admin interface. However, Django will still set and retrieve the id during model operations automatically. This is important for maintaining data integrity as the primary key should not be modified manually to prevent issues with referencing related models or managing database constraints.\n```\n\n2. The explanation on prepopulated_fields in the PostAdmin class could be more explicit:\n - It\'s a feature of Django Admin that lets you auto-fill fields during form creation if they are populated by other fields, saving time and reducing errors when data is entered manually into forms. In this case, \'slug\' field will prepopulate with values from the \'title\' field upon form save.\n\n3. The concept of "pushing to GitHub" might be confusing for those unfamiliar with version control systems like Git. You could elaborate on what a commit is and how it relates to tracking changes in your codebase:\n - A commit is an operation that records the state of the source files in a snapshot, allowing you to keep track of all changes made over time. Pushing to GitHub means transferring these commits from your local machine to the remote repository on GitHub, effectively synchronizing your development work with the rest of the team or making it accessible for others.\n\nThese examples aim to provide further explanation and context where needed to enhance understanding of the document\'s content.'}, 'done_reason': 'stop', 'done': True, 'total_duration': 21721783042, 'load_duration': 3862179375, 'prompt_eval_count': 1760, 'prompt_eval_duration': 3639336000, 'eval_count': 478, 'eval_duration': 14190200000}
# Model: qwen2
# {'model': 'qwen2', 'created_at': '2024-06-21T12:24:35.292881Z', 'message': {'role': 'assistant', 'content': 'The documentation appears clear and well-written, with several examples demonstrating key concepts step-by-step. Here are a few aspects where additional clarity might help:\n\n1. **Django Admin Site**: It\'s mentioned that the `admin.site` object represents the admin site and routes paths like `admin/` to `admin.site.urls`. However, it would be helpful if there was a brief explanation or example showing how models register with this site.\n\n2. **Customizing ModelAdmins**: While many customizations of ModelAdmin are listed (like `list_display`, `prepopulated_fields`, etc.), an overview of what each does and some simple examples could help readers understand their usage better. For instance:\n\n   ```python\n   class PostAdmin(admin.ModelAdmin):\n       list_display = (\'title\', \'author\', \'status\')\n       prepopulated_fields = {\'slug\': (\'title\',)}\n   ```\n\n3. **PostForm Usage**: In the section on creating a post, it might benefit readers if there was more context about how to use the form after creation: \n\n   - How does the "Save" action work?\n   - Does it create a new Post instance or update an existing one?\n\n4. **URLs and Path Routing**: The explanation of routing paths (`admin/`) could be clearer, especially for those unfamiliar with Django\'s URL handling mechanics.\n\n5. **Code Snippets in Code Blocks**: Some code snippets are not enclosed in code blocks (e.g., `python3 manage.py runserver 0.0.0.0:8000`). This can make the documentation slightly less readable since it requires readers to visually distinguish between code and regular text.\n\n6. **Link Usage for Documentation**: The document provides links to various Django documentation pages. It might be beneficial if these links are converted into actual clickable hyperlinks or at least made more prominent (like using a different color).\n\n7. **Challenges/Exercises**: The challenges section is provided, but without context on how the reader should approach them or what tools they need for implementation.\n\nOverall, while the document is quite comprehensive and detailed in explaining Django concepts, additional context and some form of interactivity (like quizzes) might enhance its educational value further.'}, 'done_reason': 'stop', 'done': True, 'total_duration': 27276124708, 'load_duration': 6824258625, 'prompt_eval_count': 1691, 'prompt_eval_duration': 4852559000, 'eval_count': 451, 'eval_duration': 15536432000}
# Model: llama3
# {'model': 'llama3', 'created_at': '2024-06-21T12:24:59.64121Z', 'message': {'role': 'assistant', 'content': 'The feedback suggests that the document is generally clear and easy to understand for those with basic knowledge of Django, but may benefit from additional explanation or clarification on certain topics. Specifically:\n\n* The terms "model", "admin site", and "terminal" may require more explanation for those new to Django.\n* More detailed explanations are needed for certain concepts, such as:\n\t+ Why including non-editable fields like \'id\' in the PostAdmin class is important\n\t+ How prepopulated_fields works in the context of form creation\n\t+ What a commit is and how it relates to tracking changes in codebase\n* Additional clarification would be helpful for certain sections, such as:\n\t+ Django Admin Site: providing an example or explanation on how models register with this site\n\t+ Customizing ModelAdmins: providing more information on what each customization does and examples of usage\n\t+ PostForm Usage: providing more context on how to use the form after creation (e.g., creating a new instance vs updating an existing one)\n* Minor formatting issues, such as not enclosing code snippets in code blocks, may detract from readability.\n* The document could benefit from making links to external documentation pages into clickable hyperlinks or using a different color scheme.\n\nOverall, the feedback suggests that while the document is comprehensive and well-written, it could benefit from additional context and clarity on certain topics to enhance its educational value.'}, 'done_reason': 'stop', 'done': True, 'total_duration': 24346061500, 'load_duration': 7198565583, 'prompt_eval_count': 2044, 'prompt_eval_duration': 6402878000, 'eval_count': 285, 'eval_duration': 10728994000}
# Model: llama3-gradient
# The overall feedback is overwhelmingly positive with a few minor areas for improvement in terms of content and formatting, such as removing duplication, varying instructions slightly each time they appear and providing more details or clarification where necessary. The document provides clear instructions on how to use Django's ModelAdmin and admin.site.register to create an admin interface for a custom model, as well as other options available in the Django ModelAdmin documentation.

# %%
import ollama

# Define the questions
questions = [
    "Are there any repeated sections or sentences in the document?",
    "Are there any contradictions or logical errors in the document?",
    "Does the narrative flow smoothly and logically throughout the document?",
    "Are there any parts of the document that are unclear or difficult to understand?"
]

# Define the language models to use
models = ['mistral', 'phi3', 'qwen2']

# Initialize an empty list to store all answers from each model for all questions
all_answers = []

# Iterate over each model
for model in models:
    print(f"Model: {model}")  # Print the name of the current model
    model_answers = []
    # For each question, get the answer from this model
    for question in questions:
        print(f"Question: {question}")  # Print the original text of the question
        messages = [
            {
                'role': 'system',
                'content': f'Use the following document to answer the question: {pdf_text}',
            },
            {
                'role': 'user',
                'content': question,
            },
        ]
        response = ollama.chat(model=model, messages=messages)
        model_answers.append(response['message']['content'])
    # After answering all questions with this model, add these answers to the list of all answers
    all_answers.append(model_answers)

# Now that we have answered all questions with each model, synthesize the answers with Llama3
llama3_synthesis = []
for i in range(len(questions)):  # For each question
    question_answers = [model_answers[i] for model_answers in all_answers]  # Get the answers to this question from all models
    synthesis_question = "Summarize the following feedback on the document: " + ", ".join(question_answers)
    messages = [
        {
            'role': 'system',
            'content': f'Use the following feedback to answer the question: {", ".join(question_answers)}',
        },
        {
            'role': 'user',
            'content': synthesis_question,
        },
    ]
    print("Model: llama3")  # Print the name of Llama3 model for this part
    final_response = ollama.chat(model='llama3', messages=messages)
    llama3_synthesis.append(final_response['message']['content'])

# Finally, use Llama3-gradient to summarize all the feedback from Llama3's synthesis
final_question = "Summarize the overall feedback on the document: " + ", ".join(llama3_synthesis)
messages = [
    {
        'role': 'system',
        'content': f'Use the following feedback to answer the question: {", ".join(llama3_synthesis)}',
    },
    {
        'role': 'user',
        'content': final_question,
    },
]
print("Model: llama3-gradient")  # Print the name of Llama3-gradient model for this part
final_synthesis = ollama.chat(model='llama3-gradient', messages=messages)
print(final_synthesis['message']['content'])
# Out:
# Model: mistral
# Question: Are there any repeated sections or sentences in the document?
# Question: Are there any contradictions or logical errors in the document?
# Question: Does the narrative flow smoothly and logically throughout the document?
# Question: Are there any parts of the document that are unclear or difficult to understand?
# Model: phi3
# Question: Are there any repeated sections or sentences in the document?
# Question: Are there any contradictions or logical errors in the document?
# Question: Does the narrative flow smoothly and logically throughout the document?
# Question: Are there any parts of the document that are unclear or difficult to understand?
# Model: qwen2
# Question: Are there any repeated sections or sentences in the document?
# Question: Are there any contradictions or logical errors in the document?
# Question: Does the narrative flow smoothly and logically throughout the document?
# Question: Are there any parts of the document that are unclear or difficult to understand?
# Model: llama3
# Model: llama3
# Model: llama3
# Model: llama3
# Model: llama3-gradient
# The overall feedback on the document is positive. The main suggestion is to address the repetition in sections and sentences. Specifically, there should be separate subheadings for repeated sections like "Launching", "Models List", "Add Post" etc. There are repeated sentences about how to create editable fields which should all be moved to one single concise paragraph or combined into a new subheading. The same with using the phrase "the Django admin site". This will improve the overall readability of the document and make it easy for readers to follow along.

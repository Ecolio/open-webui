# %%
# import the pdf:
# for local file
from magic_doc.docconv import DocConverter
converter = DocConverter(s3_config=None)
markdown_content, time_cost = converter.convert("/Users/lijou/Documents/Documents/Project/Notes_Docs/PreAward/exemples/Binder1.pdf", conv_timeout=300)

print(markdown_content)
# Out:
# 2024-07-17 11:34:14.953 | INFO     | magic_pdf.libs.pdf_check:detect_invalid_chars:57 - cid_count: 0, text_len: 43137, cid_chars_radio: 0.0
# 2024-07-17 11:34:15.029 | INFO     | magic_doc.contrib.pdf.pdf_extractor:run:70 - stream io data is digital pdf
# Call: [HORIZON-CL6-2024-FARM2FORK-01-1] — [Agro-pastoral/outdoor livestock systems and wildlife management]
#
# Part B - Page 1 of 50
#
# COHABITATION AND OPTIMAL RECONCILIATION: INTEGRATING TERRITORIAL TRANSFORMATIONS AND ECOLOGICAL RESILIENCE
#
# CRITTER
#
# [This document is tagged. Do not delete the tags; they are needed for processing.] #@APP-FORM-HERIAIA@# List of participants
#
# PARTICIPANT NO. PARTICIPANT ORGANISATION NAME SHORT NAME COUNTRY
#
# 1 (Coordinator) Syddansk Universitet SDU DK
#
# 2 Lapin Yliopisto UOL FI
#
# 3 Università degli Studi di Padova UNIPD IT
#
# 4 Centro de Investigacion y Tecnologia Agroalimentaria de Aragon CITA ES
#
# 5 Association WWF Bulgaria WWF-BG BG
#
# 6 WWF Slovensko WWF-SK SK
#
# ...

# %%
from nltk import word_tokenize
import re
import math


def split_document(text):
    # Perform case-insensitive search for the sections
    sections = re.split(r'(?i)2\. impact', text)
    if len(sections) > 1:
        sections[1] = '2. Impact' + sections[1]
    else:
        raise ValueError("Section '2. Impact' not found in the document.")

    sections = [re.split(r'(?i)3\. quality and efficiency of the implementation', section) for section in sections]
    flattened_sections = [item for sublist in sections for item in sublist]
    if len(flattened_sections) == 3:
        flattened_sections[2] = '3. Quality And Efficiency Of The Implementation' + flattened_sections[2]
    else:
        raise ValueError("Section '3. Quality And Efficiency Of The Implementation' not found in the document.")

    return flattened_sections

# Initialize an empty list to store all answers from each personality for all questions
all_answers = []

document_text = markdown_content  # Assign your document content here
# Divide the document into sections or paragraphs, and assign a unique identifier to each section
sections = split_document(document_text)
section_ids = [f'Section {i+1}' for i in range(len(sections))]

# Define the section titles for context (adjusted to match the number of sections)
section_titles = [
    "Introduction and Excellence",
    "Impact",
    "Quality and Efficiency of the Implementation"
]

# Print the chunks size with the name of the sections in front of each chunk word count
section_word_counts = []
for i, section in enumerate(sections):
    word_count = len(word_tokenize(section))
    section_word_counts.append(word_count)
    title = section_titles[i % len(section_titles)]
    print(f'{title}: {word_count} words')

# Calculate the max word count and add 20%
max_word_count = max(section_word_counts)
context_window = int(max_word_count * 1.2)

# Round up to the nearest 10,000
context_window = math.ceil(context_window / 10000) * 10000

print(f'Max word count in sections: {max_word_count}')
print(f'Context window (max word count + 20%): {context_window}')
# Out:
# Introduction and Excellence: 16597 words
# Impact: 9719 words
# Quality and Efficiency of the Implementation: 12405 words
# Max word count in sections: 16597
# Context window (max word count + 20%): 20000

# %%
# Define the refined personalities and their corresponding parameters
# Define personalities and their parameters
personalities_parameters = {
    'Highly analytical evaluator, focusing on verifying the accuracy of data, identifying logical inconsistencies, and ensuring that arguments are supported by evidence.': {
        'model': 'Mathstral',
        'temperature': 0.3,
        'top_p': 0.8,
        'frequency_penalty': 1.5,
        'presence_penalty': 1.2
    },
    'Collaboration expert, emphasizing teamwork and collaboration, looking for evidence of successful collaborations, stakeholder engagement, and potential for future partnerships.': {
        'model': 'Qwen2',
        'temperature': 0.6,
        'top_p': 0.9,
        'frequency_penalty': 1.0,
        'presence_penalty': 1.0
    },
    'Innovation and impact specialist, forward-thinking, evaluating the grant application based on its potential to drive innovation, create new opportunities, and generate significant impact.': {
        'model': 'Gemma2',
        'temperature': 0.8,
        'top_p': 0.95,
        'frequency_penalty': 0.8,
        'presence_penalty': 1.0
    },
    'Project management expert, assessing the quality and efficiency of the implementation, including risk management, resource allocation, and work plan structure.': {
        'model': 'interlm2',
        'temperature': 0.5,
        'top_p': 0.9,
        'frequency_penalty': 1.0,
        'presence_penalty': 1.0
    }
}

# Define the refined questions
questions = [
    "Are all sections of the document clearly written and complete, with no repeated sections or sentences? Are there any contradictions, inconsistencies, or logical errors in the document?",
    "Does the narrative flow smoothly and logically throughout the document, and is the scientific and technical content accurate and robust?",
    "Does the document highlight the innovative aspects of the project, provide a clear explanation of the potential impact and benefits, and present realistic and achievable objectives with a detailed plan for implementation and management?",
    "Does the document demonstrate effective engagement with relevant stakeholders and provide examples of successful collaborations or potential for future collaborations?",
    "Is the proposed methodology sound, and does it include interdisciplinary approaches and appropriate consideration of gender dimensions and open science practices?",
    "Are the pathways to achieve the expected outcomes and impacts credible, and are the measures to maximize these impacts suitable and well-described?",
    "Is the work plan detailed and efficient, with a clear allocation of resources and roles? Are risks identified and mitigation measures well-defined?"
]

# %%
# Define the refined personalities and their corresponding parameters
# Define personalities and their parameters
personalities_parameters = {
    'Highly analytical evaluator, focusing on verifying the accuracy of data, identifying logical inconsistencies, and ensuring that arguments are supported by evidence.': {
        'model': 'Mathstral',
        'temperature': 0.3,
        'top_p': 0.8,
        'frequency_penalty': 1.5,
        'presence_penalty': 1.2
    },
    'Collaboration expert, emphasizing teamwork and collaboration, looking for evidence of successful collaborations, stakeholder engagement, and potential for future partnerships.': {
        'model': 'Qwen2',
        'temperature': 0.6,
        'top_p': 0.9,
        'frequency_penalty': 1.0,
        'presence_penalty': 1.0
    },
    'Innovation and impact specialist, forward-thinking, evaluating the grant application based on its potential to drive innovation, create new opportunities, and generate significant impact.': {
        'model': 'Gemma2',
        'temperature': 0.8,
        'top_p': 0.95,
        'frequency_penalty': 0.8,
        'presence_penalty': 1.0
    },
    'Project management expert, assessing the quality and efficiency of the implementation, including risk management, resource allocation, and work plan structure.': {
        'model': 'interlm2',
        'temperature': 0.5,
        'top_p': 0.9,
        'frequency_penalty': 1.0,
        'presence_penalty': 1.0
    }
}

# Define the refined questions
questions_headers = [
    "Clarity, Consistency, and Accuracy",
    "Innovation, Impact, and Collaboration",
    "Methodology, Implementation, and Risk Management"
]

questions = [
    "Are all sections of the document clearly written and complete, with no repeated sections or sentences? Are there any contradictions, inconsistencies, or logical errors in the document? Does the narrative flow smoothly and logically throughout the document, and is the scientific and technical content accurate and robust?",
    "Does the document highlight the innovative aspects of the project, provide a clear explanation of the potential impact and benefits, and present realistic and achievable objectives with a detailed plan for implementation and management? Does the document demonstrate effective engagement with relevant stakeholders and provide examples of successful collaborations or potential for future collaborations?",
    "Is the proposed methodology sound, including interdisciplinary approaches, consideration of gender dimensions, and open science practices? Are the pathways to achieve the expected outcomes and impacts credible, and are the measures to maximize these impacts suitable and well-described? Is the work plan detailed and efficient, with a clear allocation of resources and roles? Are risks identified and mitigation measures well-defined?"
]

# %%
import ollama
# Primary analysis of the sections
# Initialize an empty list to store all answers from each personality for all questions
all_answers = []

# Iterate over each personality
for personality, params in personalities_parameters.items():
    print(f"Personality: {personality}")
    model_answers = []
    # For each question, get the answer based on this personality
    for question_header, question in zip(questions_headers, questions):
        print(f"Question Header: {question_header}")
        feedback = []
        # Iterate over each section in the document
        for section_id, section, title in zip(section_ids, sections, section_titles):
            print(f"Section: {title}")
            messages = [
                {
                    'role': 'system',
                    'content': f'You are {personality}. Use the following section of the document, titled "{title}", to answer the question. Be sure to provide a summary of your findings at the end.\n\nDocument: {section}',
                },
                {
                    'role': 'user',
                    'content': question,
                },
            ]
            # Set options including the increased context window and custom parameters
            options = {
                "num_ctx": context_window,
                "temperature": params['temperature'],
                "top_p": params['top_p'],
                "frequency_penalty": params['frequency_penalty'],
                "presence_penalty": params['presence_penalty']
            }
            response = ollama.chat(model=params['model'], messages=messages, options=options)
            # If the model finds any issues in the section, add a reference to the feedback
            if 'issue' in response['message']['content'].lower():
                feedback.append(f"{section_id}: {response['message']['content']}")
        model_answers.append('\n'.join(feedback))
    # After answering all questions with this personality, add these answers to the list of all answers
    all_answers.append(model_answers)

# %%
import ollama



# Primary analysis of the sections
# Initialize an empty list to store all answers from each personality for all questions
all_answers = []

# Iterate over each personality
for personality, params in personalities_parameters.items():
    print(f"Personality: {personality}")
    model_answers = []
    # For each question, get the answer based on this personality
    for question in questions:
        print(f"Question: {question}")
        feedback = []
        # Iterate over each section in the document
        for section_id, section, title in zip(section_ids, sections, section_titles):
            print(f"Section: {title}")
            messages = [
                {
                    'role': 'system',
                    'content': f'You are {personality}. Use the following section of the document, titled "{title}", to answer the question. Be sure to provide a summary of your findings at the end.\n\nDocument: {section}',
                },
                {
                    'role': 'user',
                    'content': question,
                },
            ]
            # Set options including the increased context window and custom parameters
            options = {
                "num_ctx": context_window,
                "temperature": params['temperature'],
                "top_p": params['top_p'],
                "frequency_penalty": params['frequency_penalty'],
                "presence_penalty": params['presence_penalty']
            }
            response = ollama.chat(model=params['model'], messages=messages, options=options)
            # If the model finds any issues in the section, add a reference to the feedback
            if 'issue' in response['message']['content'].lower():
                feedback.append(f"{section_id}: {response['message']['content']}")
        model_answers.append('\n'.join(feedback))
    # After answering all questions with this personality, add these answers to the list of all answers
    all_answers.append(model_answers)
# Out:
# Personality: Highly analytical evaluator, focusing on verifying the accuracy of data, identifying logical inconsistencies, and ensuring that arguments are supported by evidence.
# Question: Evaluate the overall structure and content of the document. Ensure that the narrative flows logically, the scientific and technical content is accurate, and the project's innovative aspects, potential impact, and methodology are well-explained. Identify any logical errors, inconsistencies, or repetitions.Does the document highlight the innovative aspects of the project, provide a clear explanation of the potential impact and benefits, and present realistic and achievable objectives with a detailed plan for implementation and management?
# Section: Introduction and Excellence
# Section: Impact
# Section: Quality and Efficiency of the Implementation
# ...

# %%
# Now that we have answered all questions with each model, synthesize the answers with gemma2
gemma2_synthesis = []
for i in range(len(questions)):  # For each question
    question_answers = [model_answers[i] for model_answers in all_answers]  # Get the answers to this question from all models
    synthesis_question = "Summarize and consolidate the following feedback on the document: " + ", ".join(question_answers)
    messages = [
        {
            'role': 'system',
            'content': f'You are a highly skilled synthetic analyzer. Your task is to summarize, consolidate and present in a coherent manner the feedback provided by multiple models on the document: {", ".join(question_answers)}. Ensure to highlight any common insights or discrepancies from different perspectives.',
        },
        {
            'role': 'user',
            'content': synthesis_question,
        },
    ]
    final_response = ollama.chat(model='gemma2', messages=messages)
    gemma2_synthesis.append(final_response['message']['content'])

# Print the synthesized answers once
print("Model: gemma2")
for i, answer in enumerate(gemma2_synthesis):
    print(f"Question: {questions[i]}")
    print(answer)

# %%
# Use llama3-gradient to summarize all the feedback from gemma2's synthesis
final_question = f"Using the provided feedback and the context of the document: '{document_text}', summarize the overall feedback on the document: " + ", ".join(gemma2_synthesis)
messages = [
    {
        'role': 'system',
        'content': f'Use the following feedback to answer the question and properly reference parts of the document when necessary: {", ".join(gemma2_synthesis)}',
    },
    {
        'role': 'user',
        'content': final_question,
    },
]
# Set options including the increased context window
options = {
    "num_ctx": 60000  # Use full advantage of the 50k token context window
}
print("Model: llama3-gradient")  # Print the name of Llama3-gradient model for this part
final_synthesis = ollama.chat(model='llama3-gradient', messages=messages, options=options)
print(final_synthesis['message']['content'])
